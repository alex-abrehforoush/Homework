# %%
import os
import time
import random
import cv2
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader, TensorDataset
import torchvision.transforms as transforms
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np
import datetime as dt

# from moviepy.editor import *
# %matplotlib inline

# %% [markdown]
# ### Parameters & Hyper-parameters

# %%
group_id = 1
test_size = 0.2
batch_size = 4

height, width = 64, 64
num_frames = 20

# Specify the path to the directory containing the folders
DATASET_DIR = "../data/UCF50/" + str(group_id)

# List all classes in the specified path
folders = [folder for folder in os.listdir(DATASET_DIR) if os.path.isdir(os.path.join(DATASET_DIR, folder))]

CLASSES_LIST = folders

# %%
plt.figure(figsize=(50, 50))
all_classes_names = os.listdir(DATASET_DIR)

for counter, selected_class_Name in enumerate(all_classes_names, 1):
    video_files_names_list = os.listdir(f'../data/UCF50/{group_id}/{selected_class_Name}')

    # Check if there are video files in the folder
    if video_files_names_list:
        selected_video_file_name = random.choice(video_files_names_list)
        video_reader = cv2.VideoCapture(f'../data/UCF50/{group_id}/{selected_class_Name}/{selected_video_file_name}')
        _, bgr_frame = video_reader.read()
        video_reader.release()
        rgb_frame = cv2.cvtColor(bgr_frame, cv2.COLOR_BGR2RGB)
        cv2.putText(rgb_frame, selected_class_Name, (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2)
        plt.subplot(5, 10, counter)
        plt.imshow(rgb_frame)
        plt.axis('off')
    else:
        print(f"No video file exists in folder {selected_class_Name}")

plt.show()

# %%
# Set seed for reproducibility
mySeed = 42
np.random.seed(mySeed)
random.seed(mySeed)
torch.manual_seed(mySeed)

# %%
# Function to extract frames from a video
def frames_extraction(video_path):
    frames_list = []
    video_reader = cv2.VideoCapture(video_path)
    skip_frames_window = 1
    
    for frame_counter in range(num_frames):
        video_reader.set(cv2.CAP_PROP_POS_FRAMES, frame_counter * skip_frames_window)
        success, frame = video_reader.read()
        if not success:
            break
        
        resized_frame = cv2.resize(frame, (height, width))
        normalized_frame = resized_frame / 255
        frames_list.append(normalized_frame)
    
    video_reader.release()
    return frames_list

# Custom PyTorch dataset
class VideoDataset(Dataset):
    def __init__(self, data, labels):
        self.data = data
        self.labels = labels

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        return torch.tensor(self.data[idx]), torch.tensor(self.labels[idx])

# Function to create dataset
def create_dataset():
    features = []
    labels = []
    video_files_paths = []

    for class_index, class_name in enumerate(CLASSES_LIST):
        print(f'Extracting Data of Class: {class_name}')

        files_list = os.listdir(os.path.join(DATASET_DIR, class_name))
        for file_name in files_list:
            video_file_path = os.path.join(DATASET_DIR, class_name, file_name)

            frames = frames_extraction(video_file_path)
            if len(frames) == num_frames:
                features.append(frames)
                labels.append(class_index)
                video_files_paths.append(video_file_path)

    features = np.asarray(features)
    labels = np.array(labels)

    return features, labels, video_files_paths

# %%
# Create dataset
features, labels, video_files_paths = create_dataset()

# Convert labels to one-hot encoding using PyTorch's F.one_hot
labels_one_hot = torch.tensor(np.eye(len(CLASSES_LIST))[labels])
# Out:
# Extracting Data of Class: BaseballPitch
# Extracting Data of Class: Basketball
# Extracting Data of Class: BenchPress
# Extracting Data of Class: Biking
# Extracting Data of Class: Billiards
# Extracting Data of Class: BreastStroke
# Extracting Data of Class: CleanAndJerk
# Extracting Data of Class: Diving
# Extracting Data of Class: Drumming
# Extracting Data of Class: Fencing

# %%
# Train-test split using sklearn's train_test_split
features_train, features_test, labels_train, labels_test = train_test_split(
    features, labels_one_hot, test_size=0.2, shuffle=True, random_state=mySeed
)

# Convert data to PyTorch tensors and move to GPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")


# Convert data to PyTorch tensors
features_train = torch.tensor(features_train).to(device)
labels_train = torch.tensor(labels_train).to(device)
features_test = torch.tensor(features_test).to(device)
labels_test = torch.tensor(labels_test).to(device)

# PyTorch DataLoader
train_dataset = VideoDataset(features_train, labels_train)
train_loader = DataLoader(train_dataset, batch_size=4, shuffle=True)

validation_dataset = VideoDataset(features_test, labels_test)
validation_loader = DataLoader(validation_dataset, batch_size=4, shuffle=True)
# Out:
# <ipython-input-7-b8a25bf621b5>:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   labels_train = torch.tensor(labels_train).to(device)
# <ipython-input-7-b8a25bf621b5>:14: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   labels_test = torch.tensor(labels_test).to(device)

# %%
class LRCNModel(nn.Module):
    def __init__(self):
        super(LRCNModel, self).__init__()

        self.conv1 = nn.Conv2d(3, 16, kernel_size=(3, 3), padding='same')
        self.pool1 = nn.MaxPool2d(kernel_size=(4, 4))
        self.dropout1 = nn.Dropout(0.25)

        self.conv2 = nn.Conv2d(16, 32, kernel_size=(3, 3), padding='same')
        self.pool2 = nn.MaxPool2d(kernel_size=(4, 4))
        self.dropout2 = nn.Dropout(0.25)

        self.conv3 = nn.Conv2d(32, 64, kernel_size=(3, 3), padding='same')
        self.pool3 = nn.MaxPool2d(kernel_size=(2, 2))
        self.dropout3 = nn.Dropout(0.25)

        self.conv4 = nn.Conv2d(64, 64, kernel_size=(3, 3), padding='same')
        self.pool4 = nn.MaxPool2d(kernel_size=(2, 2))

        self.flatten = nn.Flatten()
        self.lstm = nn.LSTM(64, 32)
        self.fc = nn.Linear(32, len(CLASSES_LIST))

    def forward(self, x):
        # Reshape input tensor to [batch_size * num_frames, channels, height, width]
        x = x.view(-1, x.shape[2], x.shape[3], x.shape[4])
        
        # Permute dimensions for convolutional layers
        x = x.permute(0, 3, 1, 2)

        x = self.dropout1(self.pool1(F.relu(self.conv1(x))))
        x = self.dropout2(self.pool2(F.relu(self.conv2(x))))
        x = self.dropout3(self.pool3(F.relu(self.conv3(x))))
        x = self.pool4(F.relu(self.conv4(x)))

        # Flatten the spatial dimensions
        x = self.flatten(x)

        # Permute dimensions for LSTM
        x = x.view(x.shape[0] // num_frames, num_frames, -1).permute(1, 0, 2)

        # Apply LSTM
        x, _ = self.lstm(x)
        x = x[-1, :, :]  # Take the output of the last time step

        # Fully connected layer
        x = self.fc(x)
        return F.softmax(x, dim=1)

# %%
# Instantiate the model and move to GPU
lrcn_model = LRCNModel().to(device)
print("Model Created Successfully!")

# before training
start_time = time.time()

# Define the loss function and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(lrcn_model.parameters())
# Out:
# Model Created Successfully!

# %%
# Training loop
num_epochs = 160

for epoch in range(num_epochs):
    lrcn_model.train()
    total_train_loss = 0
    correct_train_predictions = 0
    total_train_samples = 0

    for batch_idx, (inputs, targets) in enumerate(train_loader):
        inputs, targets = inputs.to(device), targets.to(device)

        optimizer.zero_grad()
        outputs = lrcn_model(inputs)

        loss = criterion(outputs, targets)
        loss.backward()
        optimizer.step()

        total_train_loss += loss.item()

        _, predicted = torch.max(outputs.data, 1)
        total_train_samples += targets.size(0)
        correct_train_predictions += (predicted == targets).sum().item()

    avg_train_loss = total_train_loss / len(train_loader)
    train_accuracy = correct_train_predictions / total_train_samples

    # Validation loop
    lrcn_model.eval()
    total_val_loss = 0
    correct_val_predictions = 0
    total_val_samples = 0

    with torch.no_grad():
        for batch_idx, (inputs, targets) in enumerate(validation_loader):
            inputs, targets = inputs.to(device), targets.to(device)

            outputs = lrcn_model(inputs)

            loss = criterion(outputs, targets)
            total_val_loss += loss.item()

            _, predicted = torch.max(outputs.data, 1)
            total_val_samples += targets.size(0)
            correct_val_predictions += (predicted == targets).sum().item()

    avg_val_loss = total_val_loss / len(validation_loader)
    val_accuracy = correct_val_predictions / total_val_samples

    # Print the loss and accuracy for each epoch
    print(f'Epoch [{epoch+1}/{num_epochs}], Training Loss: {avg_train_loss:.4f}, Training Accuracy: {train_accuracy:.4f}, Validation Loss: {avg_val_loss:.4f}, Validation Accuracy: {val_accuracy:.4f}')
# Out:
# Epoch [1/160], Training Loss: 2.3397, Training Accuracy: 0.1099, Validation Loss: 2.3332, Validation Accuracy: 0.0092
# Epoch [2/160], Training Loss: 2.3349, Training Accuracy: 0.1112, Validation Loss: 2.3312, Validation Accuracy: 0.0171
# Epoch [3/160], Training Loss: 2.3118, Training Accuracy: 0.1146, Validation Loss: 2.3173, Validation Accuracy: 0.0264
# Epoch [4/160], Training Loss: 2.2989, Training Accuracy: 0.1182, Validation Loss: 2.3102, Validation Accuracy: 0.0314
# Epoch [5/160], Training Loss: 2.2858, Training Accuracy: 0.1250, Validation Loss: 2.2962, Validation Accuracy: 0.0377
# Epoch [6/160], Training Loss: 2.2773, Training Accuracy: 0.1301, Validation Loss: 2.2882, Validation Accuracy: 0.0450
# Epoch [7/160], Training Loss: 2.2651, Training Accuracy: 0.1343, Validation Loss: 2.2851, Validation Accuracy: 0.0547
# Epoch [8/160], Training Loss: 2.2453, Training Accuracy: 0.1358, Validation Loss: 2.2649, Validation Accuracy: 0.0608
# Epoch [9/160], Training Loss: 2.2410, Training Accuracy: 0.1401, Validation Loss: 2.2610, Validation Accuracy: 0.0615
# Epoch [10/160], Training Loss: 2.2291, Training Accuracy: 0.1488, Validation Loss: 2.2491, Validation Accuracy: 0.0707
# Epoch [11/160], Training Loss: 2.2146, Training Accuracy: 0.1530, Validation Loss: 2.2324, Validation Accuracy: 0.0761
# Epoch [12/160], Training Loss: 2.2044, Training Accuracy: 0.1584, Validation Loss: 2.2176, Validation Accuracy: 0.0820
# Epoch [13/160], Training Loss: 2.1985, Training Accuracy: 0.1646, Validation Loss: 2.2001, Validation Accuracy: 0.0902
# Epoch [14/160], Training Loss: 2.1791, Training Accuracy: 0.1711, Validation Loss: 2.1904, Validation Accuracy: 0.0994
# Epoch [15/160], Training Loss: 2.1741, Training Accuracy: 0.1747, Validation Loss: 2.1776, Validation Accuracy: 0.1016
# Epoch [16/160], Training Loss: 2.1711, Training Accuracy: 0.1840, Validation Loss: 2.1549, Validation Accuracy: 0.1113
# Epoch [17/160], Training Loss: 2.1508, Training Accuracy: 0.1907, Validation Loss: 2.1346, Validation Accuracy: 0.1183
# Epoch [18/160], Training Loss: 2.1452, Training Accuracy: 0.1980, Validation Loss: 2.1258, Validation Accuracy: 0.1213
# Epoch [19/160], Training Loss: 2.1439, Training Accuracy: 0.2005, Validation Loss: 2.1245, Validation Accuracy: 0.1240
# Epoch [20/160], Training Loss: 2.1406, Training Accuracy: 0.2076, Validation Loss: 2.0998, Validation Accuracy: 0.1258
# Epoch [21/160], Training Loss: 2.1342, Training Accuracy: 0.2136, Validation Loss: 2.0843, Validation Accuracy: 0.1301
# Epoch [22/160], Training Loss: 2.1247, Training Accuracy: 0.2185, Validation Loss: 2.0706, Validation Accuracy: 0.1325
# Epoch [23/160], Training Loss: 2.1033, Training Accuracy: 0.2262, Validation Loss: 2.0550, Validation Accuracy: 0.1351
# Epoch [24/160], Training Loss: 2.0896, Training Accuracy: 0.2285, Validation Loss: 2.0422, Validation Accuracy: 0.1376
# Epoch [25/160], Training Loss: 2.0817, Training Accuracy: 0.2306, Validation Loss: 2.0282, Validation Accuracy: 0.1445
# Epoch [26/160], Training Loss: 2.0612, Training Accuracy: 0.2337, Validation Loss: 2.0215, Validation Accuracy: 0.1524
# Epoch [27/160], Training Loss: 2.0469, Training Accuracy: 0.2400, Validation Loss: 2.0098, Validation Accuracy: 0.1567
# Epoch [28/160], Training Loss: 2.0249, Training Accuracy: 0.2499, Validation Loss: 2.0072, Validation Accuracy: 0.1587
# Epoch [29/160], Training Loss: 2.0197, Training Accuracy: 0.2558, Validation Loss: 1.9902, Validation Accuracy: 0.1619
# Epoch [30/160], Training Loss: 2.0043, Training Accuracy: 0.2604, Validation Loss: 1.9837, Validation Accuracy: 0.1687
# Epoch [31/160], Training Loss: 1.9799, Training Accuracy: 0.2613, Validation Loss: 1.9774, Validation Accuracy: 0.1772
# Epoch [32/160], Training Loss: 1.9775, Training Accuracy: 0.2651, Validation Loss: 1.9602, Validation Accuracy: 0.1812
# Epoch [33/160], Training Loss: 1.9669, Training Accuracy: 0.2654, Validation Loss: 1.9558, Validation Accuracy: 0.1892
# Epoch [34/160], Training Loss: 1.9512, Training Accuracy: 0.2735, Validation Loss: 1.9435, Validation Accuracy: 0.1981
# Epoch [35/160], Training Loss: 1.9397, Training Accuracy: 0.2746, Validation Loss: 1.9292, Validation Accuracy: 0.2072
# Epoch [36/160], Training Loss: 1.9172, Training Accuracy: 0.2843, Validation Loss: 1.9174, Validation Accuracy: 0.2104
# Epoch [37/160], Training Loss: 1.9038, Training Accuracy: 0.2936, Validation Loss: 1.8968, Validation Accuracy: 0.2108
# Epoch [38/160], Training Loss: 1.8855, Training Accuracy: 0.2971, Validation Loss: 1.8773, Validation Accuracy: 0.2201
# Epoch [39/160], Training Loss: 1.8619, Training Accuracy: 0.3054, Validation Loss: 1.8646, Validation Accuracy: 0.2216
# Epoch [40/160], Training Loss: 1.8467, Training Accuracy: 0.3143, Validation Loss: 1.8434, Validation Accuracy: 0.2263
# Epoch [41/160], Training Loss: 1.8330, Training Accuracy: 0.3149, Validation Loss: 1.8200, Validation Accuracy: 0.2277
# Epoch [42/160], Training Loss: 1.8111, Training Accuracy: 0.3206, Validation Loss: 1.7999, Validation Accuracy: 0.2307
# Epoch [43/160], Training Loss: 1.7974, Training Accuracy: 0.3213, Validation Loss: 1.7892, Validation Accuracy: 0.2349
# Epoch [44/160], Training Loss: 1.7843, Training Accuracy: 0.3286, Validation Loss: 1.7805, Validation Accuracy: 0.2448
# Epoch [45/160], Training Loss: 1.7627, Training Accuracy: 0.3346, Validation Loss: 1.7570, Validation Accuracy: 0.2468
# Epoch [46/160], Training Loss: 1.7502, Training Accuracy: 0.3359, Validation Loss: 1.7536, Validation Accuracy: 0.2523
# Epoch [47/160], Training Loss: 1.7389, Training Accuracy: 0.3430, Validation Loss: 1.7461, Validation Accuracy: 0.2536
# Epoch [48/160], Training Loss: 1.7247, Training Accuracy: 0.3460, Validation Loss: 1.7378, Validation Accuracy: 0.2606
# Epoch [49/160], Training Loss: 1.7143, Training Accuracy: 0.3543, Validation Loss: 1.7320, Validation Accuracy: 0.2681
# Epoch [50/160], Training Loss: 1.7107, Training Accuracy: 0.3597, Validation Loss: 1.7244, Validation Accuracy: 0.2691
# Epoch [51/160], Training Loss: 1.6929, Training Accuracy: 0.3658, Validation Loss: 1.7129, Validation Accuracy: 0.2698
# Epoch [52/160], Training Loss: 1.6886, Training Accuracy: 0.3731, Validation Loss: 1.7086, Validation Accuracy: 0.2735
# Epoch [53/160], Training Loss: 1.6854, Training Accuracy: 0.3762, Validation Loss: 1.7054, Validation Accuracy: 0.2764
# Epoch [54/160], Training Loss: 1.6721, Training Accuracy: 0.3764, Validation Loss: 1.6921, Validation Accuracy: 0.2809
# Epoch [55/160], Training Loss: 1.6707, Training Accuracy: 0.3854, Validation Loss: 1.6689, Validation Accuracy: 0.2833
# Epoch [56/160], Training Loss: 1.6535, Training Accuracy: 0.3928, Validation Loss: 1.6546, Validation Accuracy: 0.2883
# Epoch [57/160], Training Loss: 1.6394, Training Accuracy: 0.3960, Validation Loss: 1.6314, Validation Accuracy: 0.2909
# Epoch [58/160], Training Loss: 1.6235, Training Accuracy: 0.3975, Validation Loss: 1.6241, Validation Accuracy: 0.2970
# Epoch [59/160], Training Loss: 1.5988, Training Accuracy: 0.3984, Validation Loss: 1.6018, Validation Accuracy: 0.3037
# Epoch [60/160], Training Loss: 1.5915, Training Accuracy: 0.4077, Validation Loss: 1.5883, Validation Accuracy: 0.3083
# Epoch [61/160], Training Loss: 1.5723, Training Accuracy: 0.4164, Validation Loss: 1.5859, Validation Accuracy: 0.3102
# Epoch [62/160], Training Loss: 1.5673, Training Accuracy: 0.4262, Validation Loss: 1.5649, Validation Accuracy: 0.3192
# Epoch [63/160], Training Loss: 1.5493, Training Accuracy: 0.4323, Validation Loss: 1.5526, Validation Accuracy: 0.3284
# Epoch [64/160], Training Loss: 1.5424, Training Accuracy: 0.4408, Validation Loss: 1.5437, Validation Accuracy: 0.3349
# Epoch [65/160], Training Loss: 1.5225, Training Accuracy: 0.4441, Validation Loss: 1.5195, Validation Accuracy: 0.3427
# Epoch [66/160], Training Loss: 1.5141, Training Accuracy: 0.4461, Validation Loss: 1.5144, Validation Accuracy: 0.3464
# Epoch [67/160], Training Loss: 1.5061, Training Accuracy: 0.4522, Validation Loss: 1.5107, Validation Accuracy: 0.3533
# Epoch [68/160], Training Loss: 1.4824, Training Accuracy: 0.4546, Validation Loss: 1.4858, Validation Accuracy: 0.3557
# Epoch [69/160], Training Loss: 1.4794, Training Accuracy: 0.4622, Validation Loss: 1.4697, Validation Accuracy: 0.3648
# Epoch [70/160], Training Loss: 1.4644, Training Accuracy: 0.4689, Validation Loss: 1.4682, Validation Accuracy: 0.3729
# Epoch [71/160], Training Loss: 1.4553, Training Accuracy: 0.4701, Validation Loss: 1.4484, Validation Accuracy: 0.3750
# Epoch [72/160], Training Loss: 1.4500, Training Accuracy: 0.4785, Validation Loss: 1.4274, Validation Accuracy: 0.3809
# Epoch [73/160], Training Loss: 1.4276, Training Accuracy: 0.4829, Validation Loss: 1.4102, Validation Accuracy: 0.3890
# Epoch [74/160], Training Loss: 1.4075, Training Accuracy: 0.4836, Validation Loss: 1.3981, Validation Accuracy: 0.3979
# Epoch [75/160], Training Loss: 1.3876, Training Accuracy: 0.4919, Validation Loss: 1.3815, Validation Accuracy: 0.4039
# Epoch [76/160], Training Loss: 1.3701, Training Accuracy: 0.4974, Validation Loss: 1.3658, Validation Accuracy: 0.4132
# Epoch [77/160], Training Loss: 1.3645, Training Accuracy: 0.5037, Validation Loss: 1.3562, Validation Accuracy: 0.4226
# Epoch [78/160], Training Loss: 1.3447, Training Accuracy: 0.5078, Validation Loss: 1.3384, Validation Accuracy: 0.4228
# Epoch [79/160], Training Loss: 1.3221, Training Accuracy: 0.5080, Validation Loss: 1.3261, Validation Accuracy: 0.4244
# Epoch [80/160], Training Loss: 1.3039, Training Accuracy: 0.5120, Validation Loss: 1.3239, Validation Accuracy: 0.4247
# Epoch [81/160], Training Loss: 1.2954, Training Accuracy: 0.5124, Validation Loss: 1.3150, Validation Accuracy: 0.4278
# Epoch [82/160], Training Loss: 1.2851, Training Accuracy: 0.5136, Validation Loss: 1.3051, Validation Accuracy: 0.4347
# Epoch [83/160], Training Loss: 1.2803, Training Accuracy: 0.5203, Validation Loss: 1.2915, Validation Accuracy: 0.4386
# Epoch [84/160], Training Loss: 1.2692, Training Accuracy: 0.5240, Validation Loss: 1.2756, Validation Accuracy: 0.4463
# Epoch [85/160], Training Loss: 1.2581, Training Accuracy: 0.5317, Validation Loss: 1.2741, Validation Accuracy: 0.4502
# Epoch [86/160], Training Loss: 1.2544, Training Accuracy: 0.5344, Validation Loss: 1.2564, Validation Accuracy: 0.4527
# Epoch [87/160], Training Loss: 1.2442, Training Accuracy: 0.5407, Validation Loss: 1.2328, Validation Accuracy: 0.4598
# Epoch [88/160], Training Loss: 1.2228, Training Accuracy: 0.5503, Validation Loss: 1.2127, Validation Accuracy: 0.4607
# Epoch [89/160], Training Loss: 1.2120, Training Accuracy: 0.5530, Validation Loss: 1.2102, Validation Accuracy: 0.4674
# Epoch [90/160], Training Loss: 1.1936, Training Accuracy: 0.5554, Validation Loss: 1.2004, Validation Accuracy: 0.4723
# Epoch [91/160], Training Loss: 1.1918, Training Accuracy: 0.5626, Validation Loss: 1.1908, Validation Accuracy: 0.4820
# Epoch [92/160], Training Loss: 1.1869, Training Accuracy: 0.5702, Validation Loss: 1.1737, Validation Accuracy: 0.4867
# Epoch [93/160], Training Loss: 1.1834, Training Accuracy: 0.5777, Validation Loss: 1.1645, Validation Accuracy: 0.4899
# Epoch [94/160], Training Loss: 1.1755, Training Accuracy: 0.5840, Validation Loss: 1.1539, Validation Accuracy: 0.4967
# Epoch [95/160], Training Loss: 1.1610, Training Accuracy: 0.5853, Validation Loss: 1.1291, Validation Accuracy: 0.5060
# Epoch [96/160], Training Loss: 1.1406, Training Accuracy: 0.5939, Validation Loss: 1.1191, Validation Accuracy: 0.5140
# Epoch [97/160], Training Loss: 1.1178, Training Accuracy: 0.5957, Validation Loss: 1.1082, Validation Accuracy: 0.5148
# Epoch [98/160], Training Loss: 1.0984, Training Accuracy: 0.5985, Validation Loss: 1.0851, Validation Accuracy: 0.5217
# Epoch [99/160], Training Loss: 1.0905, Training Accuracy: 0.6068, Validation Loss: 1.0659, Validation Accuracy: 0.5292
# Epoch [100/160], Training Loss: 1.0723, Training Accuracy: 0.6105, Validation Loss: 1.0515, Validation Accuracy: 0.5365
# Epoch [101/160], Training Loss: 1.0659, Training Accuracy: 0.6109, Validation Loss: 1.0284, Validation Accuracy: 0.5426
# Epoch [102/160], Training Loss: 1.0449, Training Accuracy: 0.6159, Validation Loss: 1.0139, Validation Accuracy: 0.5453
# Epoch [103/160], Training Loss: 1.0379, Training Accuracy: 0.6180, Validation Loss: 1.0084, Validation Accuracy: 0.5551
# Epoch [104/160], Training Loss: 1.0220, Training Accuracy: 0.6205, Validation Loss: 1.0037, Validation Accuracy: 0.5560
# Epoch [105/160], Training Loss: 1.0111, Training Accuracy: 0.6233, Validation Loss: 0.9823, Validation Accuracy: 0.5634
# Epoch [106/160], Training Loss: 0.9971, Training Accuracy: 0.6296, Validation Loss: 0.9681, Validation Accuracy: 0.5674
# Epoch [107/160], Training Loss: 0.9738, Training Accuracy: 0.6349, Validation Loss: 0.9463, Validation Accuracy: 0.5759
# Epoch [108/160], Training Loss: 0.9533, Training Accuracy: 0.6400, Validation Loss: 0.9216, Validation Accuracy: 0.5787
# Epoch [109/160], Training Loss: 0.9400, Training Accuracy: 0.6407, Validation Loss: 0.9186, Validation Accuracy: 0.5791
# Epoch [110/160], Training Loss: 0.9239, Training Accuracy: 0.6443, Validation Loss: 0.9052, Validation Accuracy: 0.5833
# Epoch [111/160], Training Loss: 0.9086, Training Accuracy: 0.6452, Validation Loss: 0.8812, Validation Accuracy: 0.5895
# Epoch [112/160], Training Loss: 0.8970, Training Accuracy: 0.6509, Validation Loss: 0.8608, Validation Accuracy: 0.5969
# Epoch [113/160], Training Loss: 0.8937, Training Accuracy: 0.6558, Validation Loss: 0.8529, Validation Accuracy: 0.6021
# Epoch [114/160], Training Loss: 0.8850, Training Accuracy: 0.6594, Validation Loss: 0.8445, Validation Accuracy: 0.6029
# Epoch [115/160], Training Loss: 0.8775, Training Accuracy: 0.6691, Validation Loss: 0.8252, Validation Accuracy: 0.6049
# Epoch [116/160], Training Loss: 0.8675, Training Accuracy: 0.6722, Validation Loss: 0.8163, Validation Accuracy: 0.6085
# Epoch [117/160], Training Loss: 0.8487, Training Accuracy: 0.6754, Validation Loss: 0.8021, Validation Accuracy: 0.6160
# Epoch [118/160], Training Loss: 0.8380, Training Accuracy: 0.6771, Validation Loss: 0.7997, Validation Accuracy: 0.6259
# Epoch [119/160], Training Loss: 0.8313, Training Accuracy: 0.6780, Validation Loss: 0.7900, Validation Accuracy: 0.6319
# Epoch [120/160], Training Loss: 0.8202, Training Accuracy: 0.6829, Validation Loss: 0.7864, Validation Accuracy: 0.6401
# Epoch [121/160], Training Loss: 0.8053, Training Accuracy: 0.6904, Validation Loss: 0.7811, Validation Accuracy: 0.6471
# Epoch [122/160], Training Loss: 0.8033, Training Accuracy: 0.6966, Validation Loss: 0.7718, Validation Accuracy: 0.6540
# Epoch [123/160], Training Loss: 0.7880, Training Accuracy: 0.6994, Validation Loss: 0.7676, Validation Accuracy: 0.6631
# Epoch [124/160], Training Loss: 0.7782, Training Accuracy: 0.7060, Validation Loss: 0.7610, Validation Accuracy: 0.6717
# Epoch [125/160], Training Loss: 0.7709, Training Accuracy: 0.7120, Validation Loss: 0.7581, Validation Accuracy: 0.6787
# Epoch [126/160], Training Loss: 0.7694, Training Accuracy: 0.7220, Validation Loss: 0.7525, Validation Accuracy: 0.6880
# Epoch [127/160], Training Loss: 0.7609, Training Accuracy: 0.7255, Validation Loss: 0.7400, Validation Accuracy: 0.6907
# Epoch [128/160], Training Loss: 0.7400, Training Accuracy: 0.7286, Validation Loss: 0.7239, Validation Accuracy: 0.6988
# Epoch [129/160], Training Loss: 0.7193, Training Accuracy: 0.7341, Validation Loss: 0.7214, Validation Accuracy: 0.7007
# Epoch [130/160], Training Loss: 0.6987, Training Accuracy: 0.7423, Validation Loss: 0.6978, Validation Accuracy: 0.7032
# Epoch [131/160], Training Loss: 0.6799, Training Accuracy: 0.7482, Validation Loss: 0.6942, Validation Accuracy: 0.7070
# Epoch [132/160], Training Loss: 0.6698, Training Accuracy: 0.7566, Validation Loss: 0.6898, Validation Accuracy: 0.7141
# Epoch [133/160], Training Loss: 0.6538, Training Accuracy: 0.7632, Validation Loss: 0.6714, Validation Accuracy: 0.7183
# Epoch [134/160], Training Loss: 0.6424, Training Accuracy: 0.7722, Validation Loss: 0.6624, Validation Accuracy: 0.7277
# Epoch [135/160], Training Loss: 0.6353, Training Accuracy: 0.7764, Validation Loss: 0.6376, Validation Accuracy: 0.7279
# Epoch [136/160], Training Loss: 0.6126, Training Accuracy: 0.7864, Validation Loss: 0.6250, Validation Accuracy: 0.7319
# Epoch [137/160], Training Loss: 0.6110, Training Accuracy: 0.7871, Validation Loss: 0.6181, Validation Accuracy: 0.7372
# Epoch [138/160], Training Loss: 0.5940, Training Accuracy: 0.7935, Validation Loss: 0.6033, Validation Accuracy: 0.7384
# Epoch [139/160], Training Loss: 0.5927, Training Accuracy: 0.7942, Validation Loss: 0.5977, Validation Accuracy: 0.7418
# Epoch [140/160], Training Loss: 0.5767, Training Accuracy: 0.8006, Validation Loss: 0.5740, Validation Accuracy: 0.7486
# Epoch [141/160], Training Loss: 0.5541, Training Accuracy: 0.8037, Validation Loss: 0.5599, Validation Accuracy: 0.7514
# Epoch [142/160], Training Loss: 0.5502, Training Accuracy: 0.8078, Validation Loss: 0.5382, Validation Accuracy: 0.7528
# Epoch [143/160], Training Loss: 0.5318, Training Accuracy: 0.8097, Validation Loss: 0.5298, Validation Accuracy: 0.7591
# Epoch [144/160], Training Loss: 0.5215, Training Accuracy: 0.8150, Validation Loss: 0.5204, Validation Accuracy: 0.7651
# Epoch [145/160], Training Loss: 0.5010, Training Accuracy: 0.8155, Validation Loss: 0.5188, Validation Accuracy: 0.7670
# Epoch [146/160], Training Loss: 0.4824, Training Accuracy: 0.8251, Validation Loss: 0.5024, Validation Accuracy: 0.7690
# Epoch [147/160], Training Loss: 0.4679, Training Accuracy: 0.8291, Validation Loss: 0.4879, Validation Accuracy: 0.7751
# Epoch [148/160], Training Loss: 0.4575, Training Accuracy: 0.8348, Validation Loss: 0.4649, Validation Accuracy: 0.7758
# Epoch [149/160], Training Loss: 0.4546, Training Accuracy: 0.8363, Validation Loss: 0.4633, Validation Accuracy: 0.7769
# Epoch [150/160], Training Loss: 0.4470, Training Accuracy: 0.8444, Validation Loss: 0.4453, Validation Accuracy: 0.7855
# Epoch [151/160], Training Loss: 0.4344, Training Accuracy: 0.8459, Validation Loss: 0.4339, Validation Accuracy: 0.7905
# Epoch [152/160], Training Loss: 0.4124, Training Accuracy: 0.8529, Validation Loss: 0.4278, Validation Accuracy: 0.7938
# Epoch [153/160], Training Loss: 0.4036, Training Accuracy: 0.8613, Validation Loss: 0.4236, Validation Accuracy: 0.7994
# Epoch [154/160], Training Loss: 0.3943, Training Accuracy: 0.8689, Validation Loss: 0.4143, Validation Accuracy: 0.8073
# Epoch [155/160], Training Loss: 0.3872, Training Accuracy: 0.8780, Validation Loss: 0.4050, Validation Accuracy: 0.8130
# Epoch [156/160], Training Loss: 0.3792, Training Accuracy: 0.8788, Validation Loss: 0.3838, Validation Accuracy: 0.8140
# Epoch [157/160], Training Loss: 0.3724, Training Accuracy: 0.8863, Validation Loss: 0.3640, Validation Accuracy: 0.8193
# Epoch [158/160], Training Loss: 0.3687, Training Accuracy: 0.8949, Validation Loss: 0.3420, Validation Accuracy: 0.8240
# Epoch [159/160], Training Loss: 0.3610, Training Accuracy: 0.8981, Validation Loss: 0.3191, Validation Accuracy: 0.8254
# Epoch [160/160], Training Loss: 0.3581, Training Accuracy: 0.9021, Validation Loss: 0.3123, Validation Accuracy: 0.8290
