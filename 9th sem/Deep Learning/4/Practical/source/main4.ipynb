# %%
import os
import time
import random
import cv2
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader, TensorDataset
import torchvision.transforms as transforms
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np
import datetime as dt

# from moviepy.editor import *
# %matplotlib inline

# %% [markdown]
# ### Parameters & Hyper-parameters

# %%
group_id = 4
test_size = 0.2
batch_size = 4

height, width = 64, 64
num_frames = 20

# Specify the path to the directory containing the folders
DATASET_DIR = "../data/UCF50/" + str(group_id)

# List all classes in the specified path
folders = [folder for folder in os.listdir(DATASET_DIR) if os.path.isdir(os.path.join(DATASET_DIR, folder))]

CLASSES_LIST = folders

# %%
plt.figure(figsize=(50, 50))
all_classes_names = os.listdir(DATASET_DIR)

for counter, selected_class_Name in enumerate(all_classes_names, 1):
    video_files_names_list = os.listdir(f'../data/UCF50/{group_id}/{selected_class_Name}')

    # Check if there are video files in the folder
    if video_files_names_list:
        selected_video_file_name = random.choice(video_files_names_list)
        video_reader = cv2.VideoCapture(f'../data/UCF50/{group_id}/{selected_class_Name}/{selected_video_file_name}')
        _, bgr_frame = video_reader.read()
        video_reader.release()
        rgb_frame = cv2.cvtColor(bgr_frame, cv2.COLOR_BGR2RGB)
        cv2.putText(rgb_frame, selected_class_Name, (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2)
        plt.subplot(5, 10, counter)
        plt.imshow(rgb_frame)
        plt.axis('off')
    else:
        print(f"No video file exists in folder {selected_class_Name}")

plt.show()

# %%
# Set seed for reproducibility
mySeed = 42
np.random.seed(mySeed)
random.seed(mySeed)
torch.manual_seed(mySeed)

# %%
# Function to extract frames from a video
def frames_extraction(video_path):
    frames_list = []
    video_reader = cv2.VideoCapture(video_path)
    video_frames_count = int(video_reader.get(cv2.CAP_PROP_FRAME_COUNT))
    skip_frames_window = max(int(video_frames_count / num_frames), 1)
    
    for frame_counter in range(num_frames):
        video_reader.set(cv2.CAP_PROP_POS_FRAMES, frame_counter * skip_frames_window)
        success, frame = video_reader.read()
        if not success:
            break
        
        resized_frame = cv2.resize(frame, (height, width))
        normalized_frame = resized_frame / 255
        frames_list.append(normalized_frame)
    
    video_reader.release()
    return frames_list

# Custom PyTorch dataset
class VideoDataset(Dataset):
    def __init__(self, data, labels):
        self.data = data
        self.labels = labels

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        return torch.tensor(self.data[idx]), torch.tensor(self.labels[idx])

# Function to create dataset
def create_dataset():
    features = []
    labels = []
    video_files_paths = []

    for class_index, class_name in enumerate(CLASSES_LIST):
        print(f'Extracting Data of Class: {class_name}')

        files_list = os.listdir(os.path.join(DATASET_DIR, class_name))
        for file_name in files_list:
            video_file_path = os.path.join(DATASET_DIR, class_name, file_name)

            frames = frames_extraction(video_file_path)
            if len(frames) == num_frames:
                features.append(frames)
                labels.append(class_index)
                video_files_paths.append(video_file_path)

    features = np.asarray(features)
    labels = np.array(labels)

    return features, labels, video_files_paths

# %%
# Create dataset
features, labels, video_files_paths = create_dataset()

# Convert labels to one-hot encoding using PyTorch's F.one_hot
labels_one_hot = torch.tensor(np.eye(len(CLASSES_LIST))[labels])
# Out:
# Extracting Data of Class: PommelHorse
# Extracting Data of Class: PullUps
# Extracting Data of Class: Punch
# Extracting Data of Class: PushUps
# Extracting Data of Class: RockClimbingIndoor
# Extracting Data of Class: RopeClimbing
# Extracting Data of Class: Rowing
# Extracting Data of Class: SalsaSpin
# Extracting Data of Class: SkateBoarding
# Extracting Data of Class: Skiing

# %%
# Train-test split using sklearn's train_test_split
features_train, features_test, labels_train, labels_test = train_test_split(
    features, labels_one_hot, test_size=0.25, shuffle=True, random_state=mySeed
)

# Convert data to PyTorch tensors and move to GPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")


# Convert data to PyTorch tensors
features_train = torch.tensor(features_train).to(device)
labels_train = torch.tensor(labels_train).to(device)
features_test = torch.tensor(features_test).to(device)
labels_test = torch.tensor(labels_test).to(device)

# PyTorch DataLoader
train_dataset = VideoDataset(features_train, labels_train)
train_loader = DataLoader(train_dataset, batch_size=4, shuffle=True)

validation_dataset = VideoDataset(features_test, labels_test)
validation_loader = DataLoader(validation_dataset, batch_size=4, shuffle=True)
# Out:
# <ipython-input-7-b8a25bf621b5>:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   labels_train = torch.tensor(labels_train).to(device)
# <ipython-input-7-b8a25bf621b5>:14: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   labels_test = torch.tensor(labels_test).to(device)

# %%
class LRCNModel(nn.Module):
    def __init__(self):
        super(LRCNModel, self).__init__()

        self.conv1 = nn.Conv2d(3, 16, kernel_size=(3, 3), padding='same')  # Assuming input frames have 3 channels (RGB)
        self.pool1 = nn.MaxPool2d(kernel_size=(4, 4))
        self.dropout1 = nn.Dropout(0.25)

        self.conv2 = nn.Conv2d(16, 32, kernel_size=(3, 3), padding='same')
        self.pool2 = nn.MaxPool2d(kernel_size=(4, 4))
        self.dropout2 = nn.Dropout(0.25)

        self.conv3 = nn.Conv2d(32, 64, kernel_size=(3, 3), padding='same')
        self.pool3 = nn.MaxPool2d(kernel_size=(2, 2))
        self.dropout3 = nn.Dropout(0.25)

        self.conv4 = nn.Conv2d(64, 64, kernel_size=(3, 3), padding='same')
        self.pool4 = nn.MaxPool2d(kernel_size=(2, 2))

        self.flatten = nn.Flatten()
        self.lstm = nn.LSTM(64, 32)
        self.fc = nn.Linear(32, len(CLASSES_LIST))

    def forward(self, x):
        # Reshape input tensor to [batch_size * num_frames, channels, height, width]
        x = x.view(-1, x.shape[2], x.shape[3], x.shape[4])
        
        # Permute dimensions for convolutional layers
        x = x.permute(0, 3, 1, 2)

        x = self.dropout1(self.pool1(F.relu(self.conv1(x))))
        x = self.dropout2(self.pool2(F.relu(self.conv2(x))))
        x = self.dropout3(self.pool3(F.relu(self.conv3(x))))
        x = self.pool4(F.relu(self.conv4(x)))

        # Flatten the spatial dimensions
        x = self.flatten(x)

        # Permute dimensions for LSTM
        x = x.view(x.shape[0] // num_frames, num_frames, -1).permute(1, 0, 2)

        # Apply LSTM
        x, _ = self.lstm(x)
        x = x[-1, :, :]  # Take the output of the last time step

        # Fully connected layer
        x = self.fc(x)
        return F.softmax(x, dim=1)

# %%
# Instantiate the model and move to GPU
lrcn_model = LRCNModel().to(device)
print("Model Created Successfully!")

# before training
start_time = time.time()

# Define the loss function and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(lrcn_model.parameters())
# Out:
# Model Created Successfully!

# %%
# Training loop
num_epochs = 160

for epoch in range(num_epochs):
    lrcn_model.train()
    total_train_loss = 0
    correct_train_predictions = 0
    total_train_samples = 0

    for batch_idx, (inputs, targets) in enumerate(train_loader):
        inputs, targets = inputs.to(device), targets.to(device)

        optimizer.zero_grad()
        outputs = lrcn_model(inputs)

        loss = criterion(outputs, targets)
        loss.backward()
        optimizer.step()

        total_train_loss += loss.item()

        _, predicted = torch.max(outputs.data, 1)
        total_train_samples += targets.size(0)
        correct_train_predictions += (predicted == targets).sum().item()

    avg_train_loss = total_train_loss / len(train_loader)
    train_accuracy = correct_train_predictions / total_train_samples

    # Validation loop
    lrcn_model.eval()
    total_val_loss = 0
    correct_val_predictions = 0
    total_val_samples = 0

    with torch.no_grad():
        for batch_idx, (inputs, targets) in enumerate(validation_loader):
            inputs, targets = inputs.to(device), targets.to(device)

            outputs = lrcn_model(inputs)

            loss = criterion(outputs, targets)
            total_val_loss += loss.item()

            _, predicted = torch.max(outputs.data, 1)
            total_val_samples += targets.size(0)
            correct_val_predictions += (predicted == targets).sum().item()

    avg_val_loss = total_val_loss / len(validation_loader)
    val_accuracy = correct_val_predictions / total_val_samples

    # Print the loss and accuracy for each epoch
    print(f'Epoch [{epoch+1}/{num_epochs}], Training Loss: {avg_train_loss:.4f}, Training Accuracy: {train_accuracy:.4f}, Validation Loss: {avg_val_loss:.4f}, Validation Accuracy: {val_accuracy:.4f}')
# Out:
# Epoch [1/160], Training Loss: 2.2850, Training Accuracy: 0.1279, Validation Loss: 2.2773, Validation Accuracy: 0.0079
# Epoch [2/160], Training Loss: 2.2775, Training Accuracy: 0.1291, Validation Loss: 2.2684, Validation Accuracy: 0.0170
# Epoch [3/160], Training Loss: 2.2625, Training Accuracy: 0.1369, Validation Loss: 2.2441, Validation Accuracy: 0.0220
# Epoch [4/160], Training Loss: 2.2381, Training Accuracy: 0.1405, Validation Loss: 2.2238, Validation Accuracy: 0.0266
# Epoch [5/160], Training Loss: 2.2184, Training Accuracy: 0.1424, Validation Loss: 2.2128, Validation Accuracy: 0.0366
# Epoch [6/160], Training Loss: 2.2125, Training Accuracy: 0.1491, Validation Loss: 2.2044, Validation Accuracy: 0.0450
# Epoch [7/160], Training Loss: 2.2102, Training Accuracy: 0.1582, Validation Loss: 2.1874, Validation Accuracy: 0.0541
# Epoch [8/160], Training Loss: 2.2054, Training Accuracy: 0.1602, Validation Loss: 2.1767, Validation Accuracy: 0.0568
# Epoch [9/160], Training Loss: 2.1931, Training Accuracy: 0.1664, Validation Loss: 2.1748, Validation Accuracy: 0.0614
# Epoch [10/160], Training Loss: 2.1878, Training Accuracy: 0.1679, Validation Loss: 2.1645, Validation Accuracy: 0.0657
# Epoch [11/160], Training Loss: 2.1795, Training Accuracy: 0.1756, Validation Loss: 2.1406, Validation Accuracy: 0.0728
# Epoch [12/160], Training Loss: 2.1564, Training Accuracy: 0.1846, Validation Loss: 2.1211, Validation Accuracy: 0.0800
# Epoch [13/160], Training Loss: 2.1465, Training Accuracy: 0.1910, Validation Loss: 2.1048, Validation Accuracy: 0.0880
# Epoch [14/160], Training Loss: 2.1279, Training Accuracy: 0.1946, Validation Loss: 2.1020, Validation Accuracy: 0.0919
# Epoch [15/160], Training Loss: 2.1069, Training Accuracy: 0.2029, Validation Loss: 2.0943, Validation Accuracy: 0.0982
# Epoch [16/160], Training Loss: 2.1054, Training Accuracy: 0.2074, Validation Loss: 2.0845, Validation Accuracy: 0.1014
# Epoch [17/160], Training Loss: 2.1004, Training Accuracy: 0.2152, Validation Loss: 2.0780, Validation Accuracy: 0.1111
# Epoch [18/160], Training Loss: 2.0829, Training Accuracy: 0.2231, Validation Loss: 2.0593, Validation Accuracy: 0.1118
# Epoch [19/160], Training Loss: 2.0788, Training Accuracy: 0.2266, Validation Loss: 2.0418, Validation Accuracy: 0.1178
# Epoch [20/160], Training Loss: 2.0755, Training Accuracy: 0.2340, Validation Loss: 2.0277, Validation Accuracy: 0.1254
# Epoch [21/160], Training Loss: 2.0638, Training Accuracy: 0.2382, Validation Loss: 2.0089, Validation Accuracy: 0.1265
# Epoch [22/160], Training Loss: 2.0483, Training Accuracy: 0.2383, Validation Loss: 1.9892, Validation Accuracy: 0.1315
# Epoch [23/160], Training Loss: 2.0255, Training Accuracy: 0.2472, Validation Loss: 1.9653, Validation Accuracy: 0.1353
# Epoch [24/160], Training Loss: 2.0193, Training Accuracy: 0.2566, Validation Loss: 1.9503, Validation Accuracy: 0.1415
# Epoch [25/160], Training Loss: 2.0179, Training Accuracy: 0.2570, Validation Loss: 1.9379, Validation Accuracy: 0.1430
# Epoch [26/160], Training Loss: 1.9932, Training Accuracy: 0.2602, Validation Loss: 1.9300, Validation Accuracy: 0.1476
# Epoch [27/160], Training Loss: 1.9745, Training Accuracy: 0.2691, Validation Loss: 1.9202, Validation Accuracy: 0.1533
# Epoch [28/160], Training Loss: 1.9603, Training Accuracy: 0.2704, Validation Loss: 1.9179, Validation Accuracy: 0.1607
# Epoch [29/160], Training Loss: 1.9472, Training Accuracy: 0.2714, Validation Loss: 1.8971, Validation Accuracy: 0.1621
# Epoch [30/160], Training Loss: 1.9293, Training Accuracy: 0.2754, Validation Loss: 1.8873, Validation Accuracy: 0.1706
# Epoch [31/160], Training Loss: 1.9224, Training Accuracy: 0.2777, Validation Loss: 1.8751, Validation Accuracy: 0.1753
# Epoch [32/160], Training Loss: 1.8974, Training Accuracy: 0.2875, Validation Loss: 1.8578, Validation Accuracy: 0.1761
# Epoch [33/160], Training Loss: 1.8933, Training Accuracy: 0.2944, Validation Loss: 1.8525, Validation Accuracy: 0.1856
# Epoch [34/160], Training Loss: 1.8891, Training Accuracy: 0.3036, Validation Loss: 1.8500, Validation Accuracy: 0.1908
# Epoch [35/160], Training Loss: 1.8658, Training Accuracy: 0.3060, Validation Loss: 1.8431, Validation Accuracy: 0.1995
# Epoch [36/160], Training Loss: 1.8521, Training Accuracy: 0.3134, Validation Loss: 1.8312, Validation Accuracy: 0.2009
# Epoch [37/160], Training Loss: 1.8371, Training Accuracy: 0.3180, Validation Loss: 1.8112, Validation Accuracy: 0.2036
# Epoch [38/160], Training Loss: 1.8169, Training Accuracy: 0.3182, Validation Loss: 1.7936, Validation Accuracy: 0.2072
# Epoch [39/160], Training Loss: 1.8023, Training Accuracy: 0.3270, Validation Loss: 1.7809, Validation Accuracy: 0.2150
# Epoch [40/160], Training Loss: 1.7853, Training Accuracy: 0.3347, Validation Loss: 1.7699, Validation Accuracy: 0.2228
# Epoch [41/160], Training Loss: 1.7620, Training Accuracy: 0.3424, Validation Loss: 1.7598, Validation Accuracy: 0.2238
# Epoch [42/160], Training Loss: 1.7574, Training Accuracy: 0.3472, Validation Loss: 1.7365, Validation Accuracy: 0.2272
# Epoch [43/160], Training Loss: 1.7375, Training Accuracy: 0.3479, Validation Loss: 1.7147, Validation Accuracy: 0.2315
# Epoch [44/160], Training Loss: 1.7237, Training Accuracy: 0.3499, Validation Loss: 1.7083, Validation Accuracy: 0.2397
# Epoch [45/160], Training Loss: 1.7010, Training Accuracy: 0.3558, Validation Loss: 1.6935, Validation Accuracy: 0.2450
# Epoch [46/160], Training Loss: 1.6934, Training Accuracy: 0.3560, Validation Loss: 1.6845, Validation Accuracy: 0.2541
# Epoch [47/160], Training Loss: 1.6779, Training Accuracy: 0.3575, Validation Loss: 1.6676, Validation Accuracy: 0.2616
# Epoch [48/160], Training Loss: 1.6574, Training Accuracy: 0.3633, Validation Loss: 1.6532, Validation Accuracy: 0.2688
# Epoch [49/160], Training Loss: 1.6384, Training Accuracy: 0.3689, Validation Loss: 1.6502, Validation Accuracy: 0.2703
# Epoch [50/160], Training Loss: 1.6264, Training Accuracy: 0.3690, Validation Loss: 1.6264, Validation Accuracy: 0.2720
# Epoch [51/160], Training Loss: 1.6245, Training Accuracy: 0.3706, Validation Loss: 1.6234, Validation Accuracy: 0.2804
# Epoch [52/160], Training Loss: 1.6110, Training Accuracy: 0.3767, Validation Loss: 1.6035, Validation Accuracy: 0.2898
# Epoch [53/160], Training Loss: 1.5950, Training Accuracy: 0.3840, Validation Loss: 1.6019, Validation Accuracy: 0.2921
# Epoch [54/160], Training Loss: 1.5808, Training Accuracy: 0.3845, Validation Loss: 1.5869, Validation Accuracy: 0.2922
# Epoch [55/160], Training Loss: 1.5690, Training Accuracy: 0.3930, Validation Loss: 1.5790, Validation Accuracy: 0.2993
# Epoch [56/160], Training Loss: 1.5670, Training Accuracy: 0.3976, Validation Loss: 1.5677, Validation Accuracy: 0.3019
# Epoch [57/160], Training Loss: 1.5434, Training Accuracy: 0.4027, Validation Loss: 1.5566, Validation Accuracy: 0.3034
# Epoch [58/160], Training Loss: 1.5344, Training Accuracy: 0.4119, Validation Loss: 1.5544, Validation Accuracy: 0.3116
# Epoch [59/160], Training Loss: 1.5254, Training Accuracy: 0.4195, Validation Loss: 1.5454, Validation Accuracy: 0.3204
# Epoch [60/160], Training Loss: 1.5216, Training Accuracy: 0.4237, Validation Loss: 1.5263, Validation Accuracy: 0.3243
# Epoch [61/160], Training Loss: 1.5065, Training Accuracy: 0.4285, Validation Loss: 1.5152, Validation Accuracy: 0.3250
# Epoch [62/160], Training Loss: 1.4872, Training Accuracy: 0.4361, Validation Loss: 1.5072, Validation Accuracy: 0.3311
# Epoch [63/160], Training Loss: 1.4781, Training Accuracy: 0.4430, Validation Loss: 1.4893, Validation Accuracy: 0.3336
# Epoch [64/160], Training Loss: 1.4552, Training Accuracy: 0.4431, Validation Loss: 1.4752, Validation Accuracy: 0.3338
# Epoch [65/160], Training Loss: 1.4352, Training Accuracy: 0.4505, Validation Loss: 1.4552, Validation Accuracy: 0.3345
# Epoch [66/160], Training Loss: 1.4312, Training Accuracy: 0.4568, Validation Loss: 1.4511, Validation Accuracy: 0.3430
# Epoch [67/160], Training Loss: 1.4260, Training Accuracy: 0.4608, Validation Loss: 1.4428, Validation Accuracy: 0.3432
# Epoch [68/160], Training Loss: 1.4165, Training Accuracy: 0.4627, Validation Loss: 1.4180, Validation Accuracy: 0.3502
# Epoch [69/160], Training Loss: 1.4072, Training Accuracy: 0.4714, Validation Loss: 1.4153, Validation Accuracy: 0.3591
# Epoch [70/160], Training Loss: 1.3848, Training Accuracy: 0.4787, Validation Loss: 1.4035, Validation Accuracy: 0.3631
# Epoch [71/160], Training Loss: 1.3768, Training Accuracy: 0.4824, Validation Loss: 1.3833, Validation Accuracy: 0.3705
# Epoch [72/160], Training Loss: 1.3634, Training Accuracy: 0.4840, Validation Loss: 1.3798, Validation Accuracy: 0.3796
# Epoch [73/160], Training Loss: 1.3485, Training Accuracy: 0.4940, Validation Loss: 1.3614, Validation Accuracy: 0.3819
# Epoch [74/160], Training Loss: 1.3386, Training Accuracy: 0.4966, Validation Loss: 1.3426, Validation Accuracy: 0.3865
# Epoch [75/160], Training Loss: 1.3238, Training Accuracy: 0.5059, Validation Loss: 1.3178, Validation Accuracy: 0.3877
# Epoch [76/160], Training Loss: 1.3203, Training Accuracy: 0.5076, Validation Loss: 1.3058, Validation Accuracy: 0.3920
# Epoch [77/160], Training Loss: 1.2988, Training Accuracy: 0.5131, Validation Loss: 1.2838, Validation Accuracy: 0.3931
# Epoch [78/160], Training Loss: 1.2927, Training Accuracy: 0.5142, Validation Loss: 1.2792, Validation Accuracy: 0.4010
# Epoch [79/160], Training Loss: 1.2736, Training Accuracy: 0.5165, Validation Loss: 1.2567, Validation Accuracy: 0.4022
# Epoch [80/160], Training Loss: 1.2583, Training Accuracy: 0.5230, Validation Loss: 1.2464, Validation Accuracy: 0.4030
# Epoch [81/160], Training Loss: 1.2538, Training Accuracy: 0.5243, Validation Loss: 1.2446, Validation Accuracy: 0.4043
# Epoch [82/160], Training Loss: 1.2294, Training Accuracy: 0.5251, Validation Loss: 1.2371, Validation Accuracy: 0.4051
# Epoch [83/160], Training Loss: 1.2234, Training Accuracy: 0.5271, Validation Loss: 1.2326, Validation Accuracy: 0.4125
# Epoch [84/160], Training Loss: 1.2171, Training Accuracy: 0.5284, Validation Loss: 1.2102, Validation Accuracy: 0.4140
# Epoch [85/160], Training Loss: 1.1974, Training Accuracy: 0.5339, Validation Loss: 1.2046, Validation Accuracy: 0.4209
# Epoch [86/160], Training Loss: 1.1913, Training Accuracy: 0.5436, Validation Loss: 1.1850, Validation Accuracy: 0.4290
# Epoch [87/160], Training Loss: 1.1741, Training Accuracy: 0.5441, Validation Loss: 1.1805, Validation Accuracy: 0.4363
# Epoch [88/160], Training Loss: 1.1643, Training Accuracy: 0.5444, Validation Loss: 1.1650, Validation Accuracy: 0.4410
# Epoch [89/160], Training Loss: 1.1616, Training Accuracy: 0.5448, Validation Loss: 1.1427, Validation Accuracy: 0.4492
# Epoch [90/160], Training Loss: 1.1595, Training Accuracy: 0.5537, Validation Loss: 1.1241, Validation Accuracy: 0.4549
# Epoch [91/160], Training Loss: 1.1518, Training Accuracy: 0.5577, Validation Loss: 1.1065, Validation Accuracy: 0.4598
# Epoch [92/160], Training Loss: 1.1360, Training Accuracy: 0.5652, Validation Loss: 1.0952, Validation Accuracy: 0.4628
# Epoch [93/160], Training Loss: 1.1110, Training Accuracy: 0.5698, Validation Loss: 1.0922, Validation Accuracy: 0.4657
# Epoch [94/160], Training Loss: 1.1036, Training Accuracy: 0.5762, Validation Loss: 1.0831, Validation Accuracy: 0.4750
# Epoch [95/160], Training Loss: 1.0944, Training Accuracy: 0.5831, Validation Loss: 1.0659, Validation Accuracy: 0.4766
# Epoch [96/160], Training Loss: 1.0865, Training Accuracy: 0.5901, Validation Loss: 1.0481, Validation Accuracy: 0.4825
# Epoch [97/160], Training Loss: 1.0710, Training Accuracy: 0.5988, Validation Loss: 1.0301, Validation Accuracy: 0.4884
# Epoch [98/160], Training Loss: 1.0684, Training Accuracy: 0.5999, Validation Loss: 1.0212, Validation Accuracy: 0.4923
# Epoch [99/160], Training Loss: 1.0505, Training Accuracy: 0.6098, Validation Loss: 1.0092, Validation Accuracy: 0.4995
# Epoch [100/160], Training Loss: 1.0357, Training Accuracy: 0.6134, Validation Loss: 0.9980, Validation Accuracy: 0.5048
# Epoch [101/160], Training Loss: 1.0212, Training Accuracy: 0.6187, Validation Loss: 0.9781, Validation Accuracy: 0.5059
# Epoch [102/160], Training Loss: 1.0151, Training Accuracy: 0.6278, Validation Loss: 0.9571, Validation Accuracy: 0.5108
# Epoch [103/160], Training Loss: 1.0052, Training Accuracy: 0.6297, Validation Loss: 0.9400, Validation Accuracy: 0.5134
# Epoch [104/160], Training Loss: 0.9962, Training Accuracy: 0.6378, Validation Loss: 0.9204, Validation Accuracy: 0.5231
# Epoch [105/160], Training Loss: 0.9770, Training Accuracy: 0.6394, Validation Loss: 0.9067, Validation Accuracy: 0.5324
# Epoch [106/160], Training Loss: 0.9618, Training Accuracy: 0.6474, Validation Loss: 0.8966, Validation Accuracy: 0.5355
# Epoch [107/160], Training Loss: 0.9485, Training Accuracy: 0.6509, Validation Loss: 0.8774, Validation Accuracy: 0.5455
# Epoch [108/160], Training Loss: 0.9414, Training Accuracy: 0.6599, Validation Loss: 0.8707, Validation Accuracy: 0.5513
# Epoch [109/160], Training Loss: 0.9206, Training Accuracy: 0.6648, Validation Loss: 0.8685, Validation Accuracy: 0.5608
# Epoch [110/160], Training Loss: 0.9015, Training Accuracy: 0.6702, Validation Loss: 0.8636, Validation Accuracy: 0.5628
# Epoch [111/160], Training Loss: 0.8923, Training Accuracy: 0.6743, Validation Loss: 0.8621, Validation Accuracy: 0.5634
# Epoch [112/160], Training Loss: 0.8885, Training Accuracy: 0.6772, Validation Loss: 0.8516, Validation Accuracy: 0.5684
# Epoch [113/160], Training Loss: 0.8832, Training Accuracy: 0.6783, Validation Loss: 0.8396, Validation Accuracy: 0.5711
# Epoch [114/160], Training Loss: 0.8695, Training Accuracy: 0.6859, Validation Loss: 0.8208, Validation Accuracy: 0.5748
# Epoch [115/160], Training Loss: 0.8627, Training Accuracy: 0.6897, Validation Loss: 0.8082, Validation Accuracy: 0.5820
# Epoch [116/160], Training Loss: 0.8395, Training Accuracy: 0.6970, Validation Loss: 0.7900, Validation Accuracy: 0.5889
# Epoch [117/160], Training Loss: 0.8274, Training Accuracy: 0.7047, Validation Loss: 0.7682, Validation Accuracy: 0.5920
# Epoch [118/160], Training Loss: 0.8191, Training Accuracy: 0.7107, Validation Loss: 0.7448, Validation Accuracy: 0.5966
# Epoch [119/160], Training Loss: 0.8040, Training Accuracy: 0.7165, Validation Loss: 0.7247, Validation Accuracy: 0.5977
# Epoch [120/160], Training Loss: 0.7929, Training Accuracy: 0.7180, Validation Loss: 0.7162, Validation Accuracy: 0.6001
# Epoch [121/160], Training Loss: 0.7769, Training Accuracy: 0.7226, Validation Loss: 0.6913, Validation Accuracy: 0.6026
# Epoch [122/160], Training Loss: 0.7722, Training Accuracy: 0.7252, Validation Loss: 0.6890, Validation Accuracy: 0.6052
# Epoch [123/160], Training Loss: 0.7602, Training Accuracy: 0.7331, Validation Loss: 0.6783, Validation Accuracy: 0.6131
# Epoch [124/160], Training Loss: 0.7455, Training Accuracy: 0.7363, Validation Loss: 0.6540, Validation Accuracy: 0.6163
# Epoch [125/160], Training Loss: 0.7301, Training Accuracy: 0.7417, Validation Loss: 0.6329, Validation Accuracy: 0.6251
# Epoch [126/160], Training Loss: 0.7199, Training Accuracy: 0.7478, Validation Loss: 0.6086, Validation Accuracy: 0.6295
# Epoch [127/160], Training Loss: 0.6955, Training Accuracy: 0.7549, Validation Loss: 0.5988, Validation Accuracy: 0.6349
# Epoch [128/160], Training Loss: 0.6717, Training Accuracy: 0.7617, Validation Loss: 0.5828, Validation Accuracy: 0.6417
# Epoch [129/160], Training Loss: 0.6648, Training Accuracy: 0.7634, Validation Loss: 0.5668, Validation Accuracy: 0.6434
# Epoch [130/160], Training Loss: 0.6458, Training Accuracy: 0.7681, Validation Loss: 0.5438, Validation Accuracy: 0.6481
# Epoch [131/160], Training Loss: 0.6446, Training Accuracy: 0.7704, Validation Loss: 0.5271, Validation Accuracy: 0.6504
# Epoch [132/160], Training Loss: 0.6350, Training Accuracy: 0.7710, Validation Loss: 0.5200, Validation Accuracy: 0.6584
# Epoch [133/160], Training Loss: 0.6105, Training Accuracy: 0.7797, Validation Loss: 0.4986, Validation Accuracy: 0.6618
# Epoch [134/160], Training Loss: 0.5989, Training Accuracy: 0.7828, Validation Loss: 0.4788, Validation Accuracy: 0.6642
# Epoch [135/160], Training Loss: 0.5779, Training Accuracy: 0.7854, Validation Loss: 0.4682, Validation Accuracy: 0.6730
# Epoch [136/160], Training Loss: 0.5724, Training Accuracy: 0.7943, Validation Loss: 0.4661, Validation Accuracy: 0.6828
# Epoch [137/160], Training Loss: 0.5548, Training Accuracy: 0.7948, Validation Loss: 0.4572, Validation Accuracy: 0.6889
# Epoch [138/160], Training Loss: 0.5467, Training Accuracy: 0.7980, Validation Loss: 0.4340, Validation Accuracy: 0.6927
# Epoch [139/160], Training Loss: 0.5242, Training Accuracy: 0.7996, Validation Loss: 0.4274, Validation Accuracy: 0.6967
# Epoch [140/160], Training Loss: 0.5020, Training Accuracy: 0.8018, Validation Loss: 0.4257, Validation Accuracy: 0.7033
# Epoch [141/160], Training Loss: 0.4872, Training Accuracy: 0.8068, Validation Loss: 0.4095, Validation Accuracy: 0.7099
# Epoch [142/160], Training Loss: 0.4824, Training Accuracy: 0.8158, Validation Loss: 0.4041, Validation Accuracy: 0.7104
# Epoch [143/160], Training Loss: 0.4725, Training Accuracy: 0.8188, Validation Loss: 0.3987, Validation Accuracy: 0.7161
# Epoch [144/160], Training Loss: 0.4649, Training Accuracy: 0.8261, Validation Loss: 0.3967, Validation Accuracy: 0.7181
# Epoch [145/160], Training Loss: 0.4527, Training Accuracy: 0.8318, Validation Loss: 0.3832, Validation Accuracy: 0.7208
# Epoch [146/160], Training Loss: 0.4341, Training Accuracy: 0.8336, Validation Loss: 0.3784, Validation Accuracy: 0.7300
# Epoch [147/160], Training Loss: 0.4300, Training Accuracy: 0.8390, Validation Loss: 0.3592, Validation Accuracy: 0.7339
# Epoch [148/160], Training Loss: 0.4140, Training Accuracy: 0.8405, Validation Loss: 0.3349, Validation Accuracy: 0.7421
# Epoch [149/160], Training Loss: 0.3940, Training Accuracy: 0.8472, Validation Loss: 0.3288, Validation Accuracy: 0.7434
# Epoch [150/160], Training Loss: 0.3857, Training Accuracy: 0.8571, Validation Loss: 0.3104, Validation Accuracy: 0.7440
# Epoch [151/160], Training Loss: 0.3627, Training Accuracy: 0.8622, Validation Loss: 0.3025, Validation Accuracy: 0.7465
# Epoch [152/160], Training Loss: 0.3541, Training Accuracy: 0.8674, Validation Loss: 0.2928, Validation Accuracy: 0.7487
# Epoch [153/160], Training Loss: 0.3313, Training Accuracy: 0.8705, Validation Loss: 0.2731, Validation Accuracy: 0.7556
# Epoch [154/160], Training Loss: 0.3202, Training Accuracy: 0.8753, Validation Loss: 0.2593, Validation Accuracy: 0.7614
# Epoch [155/160], Training Loss: 0.3129, Training Accuracy: 0.8783, Validation Loss: 0.2422, Validation Accuracy: 0.7687
# Epoch [156/160], Training Loss: 0.2938, Training Accuracy: 0.8864, Validation Loss: 0.2200, Validation Accuracy: 0.7776
# Epoch [157/160], Training Loss: 0.2816, Training Accuracy: 0.8946, Validation Loss: 0.2131, Validation Accuracy: 0.7854
# Epoch [158/160], Training Loss: 0.2681, Training Accuracy: 0.8949, Validation Loss: 0.2053, Validation Accuracy: 0.7902
# Epoch [159/160], Training Loss: 0.2498, Training Accuracy: 0.9030, Validation Loss: 0.1827, Validation Accuracy: 0.7980
# Epoch [160/160], Training Loss: 0.2291, Training Accuracy: 0.9077, Validation Loss: 0.1581, Validation Accuracy: 0.8053
