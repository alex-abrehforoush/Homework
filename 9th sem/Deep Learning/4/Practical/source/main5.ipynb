# %%
import os
import time
import random
import cv2
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader, TensorDataset
import torchvision.transforms as transforms
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np
import datetime as dt

# from moviepy.editor import *
# %matplotlib inline

# %% [markdown]
# ### Parameters & Hyper-parameters

# %%
group_id = 5
test_size = 0.2
batch_size = 4

height, width = 64, 64
num_frames = 20

# Specify the path to the directory containing the folders
DATASET_DIR = "../data/UCF50/" + str(group_id)

# List all classes in the specified path
folders = [folder for folder in os.listdir(DATASET_DIR) if os.path.isdir(os.path.join(DATASET_DIR, folder))]

CLASSES_LIST = folders

# %%
plt.figure(figsize=(50, 50))
all_classes_names = os.listdir(DATASET_DIR)

for counter, selected_class_Name in enumerate(all_classes_names, 1):
    video_files_names_list = os.listdir(f'../data/UCF50/{group_id}/{selected_class_Name}')

    # Check if there are video files in the folder
    if video_files_names_list:
        selected_video_file_name = random.choice(video_files_names_list)
        video_reader = cv2.VideoCapture(f'../data/UCF50/{group_id}/{selected_class_Name}/{selected_video_file_name}')
        _, bgr_frame = video_reader.read()
        video_reader.release()
        rgb_frame = cv2.cvtColor(bgr_frame, cv2.COLOR_BGR2RGB)
        cv2.putText(rgb_frame, selected_class_Name, (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2)
        plt.subplot(5, 10, counter)
        plt.imshow(rgb_frame)
        plt.axis('off')
    else:
        print(f"No video file exists in folder {selected_class_Name}")

plt.show()

# %%
# Set seed for reproducibility
mySeed = 42
np.random.seed(mySeed)
random.seed(mySeed)
torch.manual_seed(mySeed)

# %%
# Function to extract frames from a video
def frames_extraction(video_path):
    frames_list = []
    video_reader = cv2.VideoCapture(video_path)
    video_frames_count = int(video_reader.get(cv2.CAP_PROP_FRAME_COUNT))
    skip_frames_window = max(int(video_frames_count / num_frames), 1)
    
    for frame_counter in range(num_frames):
        video_reader.set(cv2.CAP_PROP_POS_FRAMES, frame_counter * skip_frames_window)
        success, frame = video_reader.read()
        if not success:
            break
        
        resized_frame = cv2.resize(frame, (height, width))
        normalized_frame = resized_frame / 255
        frames_list.append(normalized_frame)
    
    video_reader.release()
    return frames_list

# Custom PyTorch dataset
class VideoDataset(Dataset):
    def __init__(self, data, labels):
        self.data = data
        self.labels = labels

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        return torch.tensor(self.data[idx]), torch.tensor(self.labels[idx])

# Function to create dataset
def create_dataset():
    features = []
    labels = []
    video_files_paths = []

    for class_index, class_name in enumerate(CLASSES_LIST):
        print(f'Extracting Data of Class: {class_name}')

        files_list = os.listdir(os.path.join(DATASET_DIR, class_name))
        for file_name in files_list:
            video_file_path = os.path.join(DATASET_DIR, class_name, file_name)

            frames = frames_extraction(video_file_path)
            if len(frames) == num_frames:
                features.append(frames)
                labels.append(class_index)
                video_files_paths.append(video_file_path)

    features = np.asarray(features)
    labels = np.array(labels)

    return features, labels, video_files_paths

# %%
# Create dataset
features, labels, video_files_paths = create_dataset()

# Convert labels to one-hot encoding using PyTorch's F.one_hot
labels_one_hot = torch.tensor(np.eye(len(CLASSES_LIST))[labels])
# Out:
# Extracting Data of Class: Skijet
# Extracting Data of Class: SoccerJuggling
# Extracting Data of Class: Swing
# Extracting Data of Class: TaiChi
# Extracting Data of Class: TennisSwing
# Extracting Data of Class: ThrowDiscus
# Extracting Data of Class: TrampolineJumping
# Extracting Data of Class: VolleyballSpiking
# Extracting Data of Class: WalkingWithDog
# Extracting Data of Class: YoYo

# %%
# Train-test split using sklearn's train_test_split
features_train, features_test, labels_train, labels_test = train_test_split(
    features, labels_one_hot, test_size=0.25, shuffle=True, random_state=mySeed
)

# Convert data to PyTorch tensors and move to GPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")


# Convert data to PyTorch tensors
features_train = torch.tensor(features_train).to(device)
labels_train = torch.tensor(labels_train).to(device)
features_test = torch.tensor(features_test).to(device)
labels_test = torch.tensor(labels_test).to(device)

# PyTorch DataLoader
train_dataset = VideoDataset(features_train, labels_train)
train_loader = DataLoader(train_dataset, batch_size=4, shuffle=True)

validation_dataset = VideoDataset(features_test, labels_test)
validation_loader = DataLoader(validation_dataset, batch_size=4, shuffle=True)
# Out:
# <ipython-input-7-b8a25bf621b5>:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   labels_train = torch.tensor(labels_train).to(device)
# <ipython-input-7-b8a25bf621b5>:14: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   labels_test = torch.tensor(labels_test).to(device)

# %%
class LRCNModel(nn.Module):
    def __init__(self):
        super(LRCNModel, self).__init__()

        self.conv1 = nn.Conv2d(3, 16, kernel_size=(3, 3), padding='same')  # Assuming input frames have 3 channels (RGB)
        self.pool1 = nn.MaxPool2d(kernel_size=(4, 4))
        self.dropout1 = nn.Dropout(0.25)

        self.conv2 = nn.Conv2d(16, 32, kernel_size=(3, 3), padding='same')
        self.pool2 = nn.MaxPool2d(kernel_size=(4, 4))
        self.dropout2 = nn.Dropout(0.25)

        self.conv3 = nn.Conv2d(32, 64, kernel_size=(3, 3), padding='same')
        self.pool3 = nn.MaxPool2d(kernel_size=(2, 2))
        self.dropout3 = nn.Dropout(0.25)

        self.conv4 = nn.Conv2d(64, 64, kernel_size=(3, 3), padding='same')
        self.pool4 = nn.MaxPool2d(kernel_size=(2, 2))

        self.flatten = nn.Flatten()
        self.lstm = nn.LSTM(64, 32)
        self.fc = nn.Linear(32, len(CLASSES_LIST))

    def forward(self, x):
        # Reshape input tensor to [batch_size * num_frames, channels, height, width]
        x = x.view(-1, x.shape[2], x.shape[3], x.shape[4])
        
        # Permute dimensions for convolutional layers
        x = x.permute(0, 3, 1, 2)

        x = self.dropout1(self.pool1(F.relu(self.conv1(x))))
        x = self.dropout2(self.pool2(F.relu(self.conv2(x))))
        x = self.dropout3(self.pool3(F.relu(self.conv3(x))))
        x = self.pool4(F.relu(self.conv4(x)))

        # Flatten the spatial dimensions
        x = self.flatten(x)

        # Permute dimensions for LSTM
        x = x.view(x.shape[0] // num_frames, num_frames, -1).permute(1, 0, 2)

        # Apply LSTM
        x, _ = self.lstm(x)
        x = x[-1, :, :]  # Take the output of the last time step

        # Fully connected layer
        x = self.fc(x)
        return F.softmax(x, dim=1)

# %%
# Instantiate the model and move to GPU
lrcn_model = LRCNModel().to(device)
print("Model Created Successfully!")

# before training
start_time = time.time()

# Define the loss function and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(lrcn_model.parameters())
# Out:
# Model Created Successfully!

# %%
# Training loop
num_epochs = 160

for epoch in range(num_epochs):
    lrcn_model.train()
    total_train_loss = 0
    correct_train_predictions = 0
    total_train_samples = 0

    for batch_idx, (inputs, targets) in enumerate(train_loader):
        inputs, targets = inputs.to(device), targets.to(device)

        optimizer.zero_grad()
        outputs = lrcn_model(inputs)

        loss = criterion(outputs, targets)
        loss.backward()
        optimizer.step()

        total_train_loss += loss.item()

        _, predicted = torch.max(outputs.data, 1)
        total_train_samples += targets.size(0)
        correct_train_predictions += (predicted == targets).sum().item()

    avg_train_loss = total_train_loss / len(train_loader)
    train_accuracy = correct_train_predictions / total_train_samples

    # Validation loop
    lrcn_model.eval()
    total_val_loss = 0
    correct_val_predictions = 0
    total_val_samples = 0

    with torch.no_grad():
        for batch_idx, (inputs, targets) in enumerate(validation_loader):
            inputs, targets = inputs.to(device), targets.to(device)

            outputs = lrcn_model(inputs)

            loss = criterion(outputs, targets)
            total_val_loss += loss.item()

            _, predicted = torch.max(outputs.data, 1)
            total_val_samples += targets.size(0)
            correct_val_predictions += (predicted == targets).sum().item()

    avg_val_loss = total_val_loss / len(validation_loader)
    val_accuracy = correct_val_predictions / total_val_samples

    # Print the loss and accuracy for each epoch
    print(f'Epoch [{epoch+1}/{num_epochs}], Training Loss: {avg_train_loss:.4f}, Training Accuracy: {train_accuracy:.4f}, Validation Loss: {avg_val_loss:.4f}, Validation Accuracy: {val_accuracy:.4f}')
# Out:
# Epoch [1/160], Training Loss: 2.3666, Training Accuracy: 0.1318, Validation Loss: 2.3805, Validation Accuracy: 0.0265
# Epoch [2/160], Training Loss: 2.3591, Training Accuracy: 0.1329, Validation Loss: 2.3716, Validation Accuracy: 0.0356
# Epoch [3/160], Training Loss: 2.3441, Training Accuracy: 0.1408, Validation Loss: 2.3473, Validation Accuracy: 0.0406
# Epoch [4/160], Training Loss: 2.3197, Training Accuracy: 0.1443, Validation Loss: 2.3270, Validation Accuracy: 0.0452
# Epoch [5/160], Training Loss: 2.3000, Training Accuracy: 0.1463, Validation Loss: 2.3160, Validation Accuracy: 0.0552
# Epoch [6/160], Training Loss: 2.2941, Training Accuracy: 0.1530, Validation Loss: 2.3076, Validation Accuracy: 0.0636
# Epoch [7/160], Training Loss: 2.2918, Training Accuracy: 0.1620, Validation Loss: 2.2906, Validation Accuracy: 0.0727
# Epoch [8/160], Training Loss: 2.2870, Training Accuracy: 0.1641, Validation Loss: 2.2799, Validation Accuracy: 0.0754
# Epoch [9/160], Training Loss: 2.2747, Training Accuracy: 0.1703, Validation Loss: 2.2780, Validation Accuracy: 0.0800
# Epoch [10/160], Training Loss: 2.2694, Training Accuracy: 0.1718, Validation Loss: 2.2677, Validation Accuracy: 0.0843
# Epoch [11/160], Training Loss: 2.2611, Training Accuracy: 0.1795, Validation Loss: 2.2438, Validation Accuracy: 0.0914
# Epoch [12/160], Training Loss: 2.2380, Training Accuracy: 0.1885, Validation Loss: 2.2243, Validation Accuracy: 0.0986
# Epoch [13/160], Training Loss: 2.2281, Training Accuracy: 0.1949, Validation Loss: 2.2080, Validation Accuracy: 0.1066
# Epoch [14/160], Training Loss: 2.2095, Training Accuracy: 0.1984, Validation Loss: 2.2052, Validation Accuracy: 0.1105
# Epoch [15/160], Training Loss: 2.1885, Training Accuracy: 0.2068, Validation Loss: 2.1975, Validation Accuracy: 0.1168
# Epoch [16/160], Training Loss: 2.1870, Training Accuracy: 0.2113, Validation Loss: 2.1877, Validation Accuracy: 0.1200
# Epoch [17/160], Training Loss: 2.1820, Training Accuracy: 0.2190, Validation Loss: 2.1812, Validation Accuracy: 0.1297
# Epoch [18/160], Training Loss: 2.1645, Training Accuracy: 0.2270, Validation Loss: 2.1625, Validation Accuracy: 0.1304
# Epoch [19/160], Training Loss: 2.1604, Training Accuracy: 0.2305, Validation Loss: 2.1450, Validation Accuracy: 0.1364
# Epoch [20/160], Training Loss: 2.1571, Training Accuracy: 0.2378, Validation Loss: 2.1309, Validation Accuracy: 0.1440
# Epoch [21/160], Training Loss: 2.1454, Training Accuracy: 0.2421, Validation Loss: 2.1121, Validation Accuracy: 0.1451
# Epoch [22/160], Training Loss: 2.1299, Training Accuracy: 0.2422, Validation Loss: 2.0924, Validation Accuracy: 0.1501
# Epoch [23/160], Training Loss: 2.1071, Training Accuracy: 0.2511, Validation Loss: 2.0685, Validation Accuracy: 0.1539
# Epoch [24/160], Training Loss: 2.1009, Training Accuracy: 0.2605, Validation Loss: 2.0535, Validation Accuracy: 0.1601
# Epoch [25/160], Training Loss: 2.0995, Training Accuracy: 0.2609, Validation Loss: 2.0411, Validation Accuracy: 0.1616
# Epoch [26/160], Training Loss: 2.0748, Training Accuracy: 0.2641, Validation Loss: 2.0332, Validation Accuracy: 0.1662
# Epoch [27/160], Training Loss: 2.0561, Training Accuracy: 0.2730, Validation Loss: 2.0234, Validation Accuracy: 0.1719
# Epoch [28/160], Training Loss: 2.0419, Training Accuracy: 0.2743, Validation Loss: 2.0211, Validation Accuracy: 0.1793
# Epoch [29/160], Training Loss: 2.0288, Training Accuracy: 0.2753, Validation Loss: 2.0003, Validation Accuracy: 0.1807
# Epoch [30/160], Training Loss: 2.0109, Training Accuracy: 0.2793, Validation Loss: 1.9905, Validation Accuracy: 0.1892
# Epoch [31/160], Training Loss: 2.0040, Training Accuracy: 0.2816, Validation Loss: 1.9783, Validation Accuracy: 0.1939
# Epoch [32/160], Training Loss: 1.9790, Training Accuracy: 0.2914, Validation Loss: 1.9610, Validation Accuracy: 0.1947
# Epoch [33/160], Training Loss: 1.9749, Training Accuracy: 0.2983, Validation Loss: 1.9557, Validation Accuracy: 0.2042
# Epoch [34/160], Training Loss: 1.9707, Training Accuracy: 0.3075, Validation Loss: 1.9532, Validation Accuracy: 0.2094
# Epoch [35/160], Training Loss: 1.9474, Training Accuracy: 0.3099, Validation Loss: 1.9463, Validation Accuracy: 0.2181
# Epoch [36/160], Training Loss: 1.9337, Training Accuracy: 0.3173, Validation Loss: 1.9344, Validation Accuracy: 0.2195
# Epoch [37/160], Training Loss: 1.9187, Training Accuracy: 0.3219, Validation Loss: 1.9144, Validation Accuracy: 0.2222
# Epoch [38/160], Training Loss: 1.8985, Training Accuracy: 0.3221, Validation Loss: 1.8968, Validation Accuracy: 0.2258
# Epoch [39/160], Training Loss: 1.8839, Training Accuracy: 0.3309, Validation Loss: 1.8841, Validation Accuracy: 0.2336
# Epoch [40/160], Training Loss: 1.8669, Training Accuracy: 0.3386, Validation Loss: 1.8731, Validation Accuracy: 0.2414
# Epoch [41/160], Training Loss: 1.8436, Training Accuracy: 0.3463, Validation Loss: 1.8630, Validation Accuracy: 0.2424
# Epoch [42/160], Training Loss: 1.8390, Training Accuracy: 0.3540, Validation Loss: 1.8397, Validation Accuracy: 0.2458
# Epoch [43/160], Training Loss: 1.8191, Training Accuracy: 0.3547, Validation Loss: 1.8179, Validation Accuracy: 0.2501
# Epoch [44/160], Training Loss: 1.8053, Training Accuracy: 0.3567, Validation Loss: 1.8115, Validation Accuracy: 0.2583
# Epoch [45/160], Training Loss: 1.7826, Training Accuracy: 0.3625, Validation Loss: 1.7967, Validation Accuracy: 0.2636
# Epoch [46/160], Training Loss: 1.7750, Training Accuracy: 0.3628, Validation Loss: 1.7877, Validation Accuracy: 0.2727
# Epoch [47/160], Training Loss: 1.7595, Training Accuracy: 0.3643, Validation Loss: 1.7708, Validation Accuracy: 0.2802
# Epoch [48/160], Training Loss: 1.7390, Training Accuracy: 0.3701, Validation Loss: 1.7564, Validation Accuracy: 0.2874
# Epoch [49/160], Training Loss: 1.7334, Training Accuracy: 0.3757, Validation Loss: 1.7534, Validation Accuracy: 0.2889
# Epoch [50/160], Training Loss: 1.7214, Training Accuracy: 0.3758, Validation Loss: 1.7296, Validation Accuracy: 0.2906
# Epoch [51/160], Training Loss: 1.7195, Training Accuracy: 0.3774, Validation Loss: 1.7266, Validation Accuracy: 0.2990
# Epoch [52/160], Training Loss: 1.7060, Training Accuracy: 0.3834, Validation Loss: 1.7067, Validation Accuracy: 0.3084
# Epoch [53/160], Training Loss: 1.6900, Training Accuracy: 0.3908, Validation Loss: 1.7051, Validation Accuracy: 0.3107
# Epoch [54/160], Training Loss: 1.6758, Training Accuracy: 0.3913, Validation Loss: 1.6901, Validation Accuracy: 0.3108
# Epoch [55/160], Training Loss: 1.6640, Training Accuracy: 0.3998, Validation Loss: 1.6822, Validation Accuracy: 0.3179
# Epoch [56/160], Training Loss: 1.6620, Training Accuracy: 0.4044, Validation Loss: 1.6709, Validation Accuracy: 0.3205
# Epoch [57/160], Training Loss: 1.6398, Training Accuracy: 0.4094, Validation Loss: 1.6598, Validation Accuracy: 0.3220
# Epoch [58/160], Training Loss: 1.6376, Training Accuracy: 0.4186, Validation Loss: 1.6576, Validation Accuracy: 0.3302
# Epoch [59/160], Training Loss: 1.6286, Training Accuracy: 0.4263, Validation Loss: 1.6486, Validation Accuracy: 0.3390
# Epoch [60/160], Training Loss: 1.6248, Training Accuracy: 0.4304, Validation Loss: 1.6295, Validation Accuracy: 0.3429
# Epoch [61/160], Training Loss: 1.6097, Training Accuracy: 0.4353, Validation Loss: 1.6184, Validation Accuracy: 0.3436
# Epoch [62/160], Training Loss: 1.5904, Training Accuracy: 0.4429, Validation Loss: 1.6104, Validation Accuracy: 0.3497
# Epoch [63/160], Training Loss: 1.5813, Training Accuracy: 0.4498, Validation Loss: 1.5925, Validation Accuracy: 0.3522
# Epoch [64/160], Training Loss: 1.5584, Training Accuracy: 0.4499, Validation Loss: 1.5784, Validation Accuracy: 0.3524
# Epoch [65/160], Training Loss: 1.5384, Training Accuracy: 0.4573, Validation Loss: 1.5584, Validation Accuracy: 0.3531
# Epoch [66/160], Training Loss: 1.5344, Training Accuracy: 0.4636, Validation Loss: 1.5543, Validation Accuracy: 0.3616
# Epoch [67/160], Training Loss: 1.5292, Training Accuracy: 0.4675, Validation Loss: 1.5460, Validation Accuracy: 0.3618
# Epoch [68/160], Training Loss: 1.5197, Training Accuracy: 0.4695, Validation Loss: 1.5212, Validation Accuracy: 0.3688
# Epoch [69/160], Training Loss: 1.5104, Training Accuracy: 0.4781, Validation Loss: 1.5185, Validation Accuracy: 0.3777
# Epoch [70/160], Training Loss: 1.4880, Training Accuracy: 0.4854, Validation Loss: 1.5067, Validation Accuracy: 0.3817
# Epoch [71/160], Training Loss: 1.4800, Training Accuracy: 0.4891, Validation Loss: 1.4865, Validation Accuracy: 0.3891
# Epoch [72/160], Training Loss: 1.4666, Training Accuracy: 0.4908, Validation Loss: 1.4830, Validation Accuracy: 0.3982
# Epoch [73/160], Training Loss: 1.4517, Training Accuracy: 0.5007, Validation Loss: 1.4646, Validation Accuracy: 0.4005
# Epoch [74/160], Training Loss: 1.4418, Training Accuracy: 0.5034, Validation Loss: 1.4458, Validation Accuracy: 0.4051
# Epoch [75/160], Training Loss: 1.4270, Training Accuracy: 0.5127, Validation Loss: 1.4210, Validation Accuracy: 0.4063
# Epoch [76/160], Training Loss: 1.4235, Training Accuracy: 0.5144, Validation Loss: 1.4090, Validation Accuracy: 0.4106
# Epoch [77/160], Training Loss: 1.4020, Training Accuracy: 0.5213, Validation Loss: 1.3870, Validation Accuracy: 0.4117
# Epoch [78/160], Training Loss: 1.3959, Training Accuracy: 0.5224, Validation Loss: 1.3824, Validation Accuracy: 0.4196
# Epoch [79/160], Training Loss: 1.3768, Training Accuracy: 0.5247, Validation Loss: 1.3599, Validation Accuracy: 0.4208
# Epoch [80/160], Training Loss: 1.3615, Training Accuracy: 0.5332, Validation Loss: 1.3496, Validation Accuracy: 0.4216
# Epoch [81/160], Training Loss: 1.3570, Training Accuracy: 0.5352, Validation Loss: 1.3478, Validation Accuracy: 0.4229
# Epoch [82/160], Training Loss: 1.3326, Training Accuracy: 0.5419, Validation Loss: 1.3403, Validation Accuracy: 0.4237
# Epoch [83/160], Training Loss: 1.3266, Training Accuracy: 0.5438, Validation Loss: 1.3358, Validation Accuracy: 0.4311
# Epoch [84/160], Training Loss: 1.3203, Training Accuracy: 0.5452, Validation Loss: 1.3134, Validation Accuracy: 0.4326
# Epoch [85/160], Training Loss: 1.3006, Training Accuracy: 0.5507, Validation Loss: 1.3078, Validation Accuracy: 0.4395
# Epoch [86/160], Training Loss: 1.2945, Training Accuracy: 0.5604, Validation Loss: 1.2882, Validation Accuracy: 0.4476
# Epoch [87/160], Training Loss: 1.2773, Training Accuracy: 0.5608, Validation Loss: 1.2837, Validation Accuracy: 0.4549
# Epoch [88/160], Training Loss: 1.2675, Training Accuracy: 0.5611, Validation Loss: 1.2682, Validation Accuracy: 0.4596
# Epoch [89/160], Training Loss: 1.2648, Training Accuracy: 0.5615, Validation Loss: 1.2459, Validation Accuracy: 0.4678
# Epoch [90/160], Training Loss: 1.2627, Training Accuracy: 0.5705, Validation Loss: 1.2273, Validation Accuracy: 0.4735
# Epoch [91/160], Training Loss: 1.2550, Training Accuracy: 0.5744, Validation Loss: 1.2097, Validation Accuracy: 0.4784
# Epoch [92/160], Training Loss: 1.2392, Training Accuracy: 0.5819, Validation Loss: 1.1984, Validation Accuracy: 0.4814
# Epoch [93/160], Training Loss: 1.2142, Training Accuracy: 0.5866, Validation Loss: 1.1954, Validation Accuracy: 0.4843
# Epoch [94/160], Training Loss: 1.2068, Training Accuracy: 0.5930, Validation Loss: 1.1863, Validation Accuracy: 0.4936
# Epoch [95/160], Training Loss: 1.1976, Training Accuracy: 0.5999, Validation Loss: 1.1691, Validation Accuracy: 0.4952
# Epoch [96/160], Training Loss: 1.1897, Training Accuracy: 0.6068, Validation Loss: 1.1513, Validation Accuracy: 0.5011
# Epoch [97/160], Training Loss: 1.1742, Training Accuracy: 0.6156, Validation Loss: 1.1333, Validation Accuracy: 0.5070
# Epoch [98/160], Training Loss: 1.1716, Training Accuracy: 0.6166, Validation Loss: 1.1244, Validation Accuracy: 0.5109
# Epoch [99/160], Training Loss: 1.1537, Training Accuracy: 0.6266, Validation Loss: 1.1124, Validation Accuracy: 0.5181
# Epoch [100/160], Training Loss: 1.1389, Training Accuracy: 0.6301, Validation Loss: 1.1012, Validation Accuracy: 0.5234
# Epoch [101/160], Training Loss: 1.1244, Training Accuracy: 0.6355, Validation Loss: 1.0813, Validation Accuracy: 0.5245
# Epoch [102/160], Training Loss: 1.1183, Training Accuracy: 0.6446, Validation Loss: 1.0603, Validation Accuracy: 0.5294
# Epoch [103/160], Training Loss: 1.1084, Training Accuracy: 0.6465, Validation Loss: 1.0432, Validation Accuracy: 0.5320
# Epoch [104/160], Training Loss: 1.0994, Training Accuracy: 0.6545, Validation Loss: 1.0236, Validation Accuracy: 0.5417
# Epoch [105/160], Training Loss: 1.0802, Training Accuracy: 0.6561, Validation Loss: 1.0099, Validation Accuracy: 0.5510
# Epoch [106/160], Training Loss: 1.0650, Training Accuracy: 0.6642, Validation Loss: 0.9998, Validation Accuracy: 0.5541
# Epoch [107/160], Training Loss: 1.0517, Training Accuracy: 0.6677, Validation Loss: 0.9806, Validation Accuracy: 0.5641
# Epoch [108/160], Training Loss: 1.0446, Training Accuracy: 0.6767, Validation Loss: 0.9739, Validation Accuracy: 0.5699
# Epoch [109/160], Training Loss: 1.0238, Training Accuracy: 0.6815, Validation Loss: 0.9717, Validation Accuracy: 0.5794
# Epoch [110/160], Training Loss: 1.0047, Training Accuracy: 0.6870, Validation Loss: 0.9668, Validation Accuracy: 0.5814
# Epoch [111/160], Training Loss: 0.9955, Training Accuracy: 0.6911, Validation Loss: 0.9653, Validation Accuracy: 0.5820
# Epoch [112/160], Training Loss: 0.9917, Training Accuracy: 0.6940, Validation Loss: 0.9548, Validation Accuracy: 0.5870
# Epoch [113/160], Training Loss: 0.9864, Training Accuracy: 0.6951, Validation Loss: 0.9428, Validation Accuracy: 0.5897
# Epoch [114/160], Training Loss: 0.9727, Training Accuracy: 0.7027, Validation Loss: 0.9240, Validation Accuracy: 0.5934
# Epoch [115/160], Training Loss: 0.9659, Training Accuracy: 0.7065, Validation Loss: 0.9114, Validation Accuracy: 0.6006
# Epoch [116/160], Training Loss: 0.9427, Training Accuracy: 0.7138, Validation Loss: 0.8932, Validation Accuracy: 0.6075
# Epoch [117/160], Training Loss: 0.9306, Training Accuracy: 0.7215, Validation Loss: 0.8714, Validation Accuracy: 0.6106
# Epoch [118/160], Training Loss: 0.9223, Training Accuracy: 0.7274, Validation Loss: 0.8480, Validation Accuracy: 0.6152
# Epoch [119/160], Training Loss: 0.9072, Training Accuracy: 0.7333, Validation Loss: 0.8279, Validation Accuracy: 0.6163
# Epoch [120/160], Training Loss: 0.8961, Training Accuracy: 0.7348, Validation Loss: 0.8194, Validation Accuracy: 0.6187
# Epoch [121/160], Training Loss: 0.8801, Training Accuracy: 0.7412, Validation Loss: 0.7945, Validation Accuracy: 0.6212
# Epoch [122/160], Training Loss: 0.8754, Training Accuracy: 0.7438, Validation Loss: 0.7922, Validation Accuracy: 0.6238
# Epoch [123/160], Training Loss: 0.8634, Training Accuracy: 0.7517, Validation Loss: 0.7815, Validation Accuracy: 0.6317
# Epoch [124/160], Training Loss: 0.8487, Training Accuracy: 0.7549, Validation Loss: 0.7572, Validation Accuracy: 0.6349
# Epoch [125/160], Training Loss: 0.8333, Training Accuracy: 0.7603, Validation Loss: 0.7361, Validation Accuracy: 0.6437
# Epoch [126/160], Training Loss: 0.8231, Training Accuracy: 0.7664, Validation Loss: 0.7118, Validation Accuracy: 0.6481
# Epoch [127/160], Training Loss: 0.7987, Training Accuracy: 0.7735, Validation Loss: 0.7020, Validation Accuracy: 0.6535
# Epoch [128/160], Training Loss: 0.7749, Training Accuracy: 0.7803, Validation Loss: 0.6860, Validation Accuracy: 0.6603
# Epoch [129/160], Training Loss: 0.7680, Training Accuracy: 0.7820, Validation Loss: 0.6700, Validation Accuracy: 0.6620
# Epoch [130/160], Training Loss: 0.7490, Training Accuracy: 0.7867, Validation Loss: 0.6470, Validation Accuracy: 0.6667
# Epoch [131/160], Training Loss: 0.7478, Training Accuracy: 0.7890, Validation Loss: 0.6303, Validation Accuracy: 0.6690
# Epoch [132/160], Training Loss: 0.7382, Training Accuracy: 0.7896, Validation Loss: 0.6232, Validation Accuracy: 0.6770
# Epoch [133/160], Training Loss: 0.7137, Training Accuracy: 0.7983, Validation Loss: 0.6018, Validation Accuracy: 0.6804
# Epoch [134/160], Training Loss: 0.7021, Training Accuracy: 0.8014, Validation Loss: 0.5820, Validation Accuracy: 0.6828
# Epoch [135/160], Training Loss: 0.6811, Training Accuracy: 0.8040, Validation Loss: 0.5714, Validation Accuracy: 0.6916
# Epoch [136/160], Training Loss: 0.6756, Training Accuracy: 0.8129, Validation Loss: 0.5693, Validation Accuracy: 0.7014
# Epoch [137/160], Training Loss: 0.6580, Training Accuracy: 0.8134, Validation Loss: 0.5604, Validation Accuracy: 0.7075
# Epoch [138/160], Training Loss: 0.6499, Training Accuracy: 0.8166, Validation Loss: 0.5372, Validation Accuracy: 0.7113
# Epoch [139/160], Training Loss: 0.6274, Training Accuracy: 0.8182, Validation Loss: 0.5306, Validation Accuracy: 0.7153
# Epoch [140/160], Training Loss: 0.6052, Training Accuracy: 0.8204, Validation Loss: 0.5289, Validation Accuracy: 0.7219
# Epoch [141/160], Training Loss: 0.5904, Training Accuracy: 0.8254, Validation Loss: 0.5127, Validation Accuracy: 0.7285
# Epoch [142/160], Training Loss: 0.5856, Training Accuracy: 0.8344, Validation Loss: 0.5073, Validation Accuracy: 0.7290
# Epoch [143/160], Training Loss: 0.5757, Training Accuracy: 0.8374, Validation Loss: 0.5019, Validation Accuracy: 0.7347
# Epoch [144/160], Training Loss: 0.5681, Training Accuracy: 0.8447, Validation Loss: 0.4999, Validation Accuracy: 0.7367
# Epoch [145/160], Training Loss: 0.5559, Training Accuracy: 0.8504, Validation Loss: 0.4864, Validation Accuracy: 0.7394
# Epoch [146/160], Training Loss: 0.5373, Training Accuracy: 0.8522, Validation Loss: 0.4816, Validation Accuracy: 0.7486
# Epoch [147/160], Training Loss: 0.5332, Training Accuracy: 0.8576, Validation Loss: 0.4624, Validation Accuracy: 0.7525
# Epoch [148/160], Training Loss: 0.5172, Training Accuracy: 0.8591, Validation Loss: 0.4381, Validation Accuracy: 0.7607
# Epoch [149/160], Training Loss: 0.4972, Training Accuracy: 0.8658, Validation Loss: 0.4320, Validation Accuracy: 0.7620
# Epoch [150/160], Training Loss: 0.4889, Training Accuracy: 0.8757, Validation Loss: 0.4136, Validation Accuracy: 0.7626
# Epoch [151/160], Training Loss: 0.4659, Training Accuracy: 0.8808, Validation Loss: 0.4057, Validation Accuracy: 0.7651
# Epoch [152/160], Training Loss: 0.4573, Training Accuracy: 0.8860, Validation Loss: 0.3960, Validation Accuracy: 0.7673
# Epoch [153/160], Training Loss: 0.4345, Training Accuracy: 0.8891, Validation Loss: 0.3763, Validation Accuracy: 0.7742
# Epoch [154/160], Training Loss: 0.4234, Training Accuracy: 0.8939, Validation Loss: 0.3625, Validation Accuracy: 0.7800
# Epoch [155/160], Training Loss: 0.4161, Training Accuracy: 0.8969, Validation Loss: 0.3454, Validation Accuracy: 0.7873
# Epoch [156/160], Training Loss: 0.3970, Training Accuracy: 0.9050, Validation Loss: 0.3232, Validation Accuracy: 0.7962
# Epoch [157/160], Training Loss: 0.3848, Training Accuracy: 0.9132, Validation Loss: 0.3163, Validation Accuracy: 0.8040
# Epoch [158/160], Training Loss: 0.3713, Training Accuracy: 0.9135, Validation Loss: 0.3085, Validation Accuracy: 0.8088
# Epoch [159/160], Training Loss: 0.3530, Training Accuracy: 0.9216, Validation Loss: 0.2859, Validation Accuracy: 0.8166
# Epoch [160/160], Training Loss: 0.3323, Training Accuracy: 0.9263, Validation Loss: 0.2613, Validation Accuracy: 0.8239
