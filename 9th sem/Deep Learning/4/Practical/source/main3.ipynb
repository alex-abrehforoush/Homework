# %%
import os
import time
import random
import cv2
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader, TensorDataset
import torchvision.transforms as transforms
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np
import datetime as dt

# from moviepy.editor import *
# %matplotlib inline

# %% [markdown]
# ### Parameters & Hyper-parameters

# %%
group_id = 3
test_size = 0.2
batch_size = 4

height, width = 64, 64
num_frames = 20

# Specify the path to the directory containing the folders
DATASET_DIR = "../data/UCF50/" + str(group_id)

# List all classes in the specified path
folders = [folder for folder in os.listdir(DATASET_DIR) if os.path.isdir(os.path.join(DATASET_DIR, folder))]

CLASSES_LIST = folders

# %%
plt.figure(figsize=(50, 50))
all_classes_names = os.listdir(DATASET_DIR)

for counter, selected_class_Name in enumerate(all_classes_names, 1):
    video_files_names_list = os.listdir(f'../data/UCF50/{group_id}/{selected_class_Name}')

    # Check if there are video files in the folder
    if video_files_names_list:
        selected_video_file_name = random.choice(video_files_names_list)
        video_reader = cv2.VideoCapture(f'../data/UCF50/{group_id}/{selected_class_Name}/{selected_video_file_name}')
        _, bgr_frame = video_reader.read()
        video_reader.release()
        rgb_frame = cv2.cvtColor(bgr_frame, cv2.COLOR_BGR2RGB)
        cv2.putText(rgb_frame, selected_class_Name, (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2)
        plt.subplot(5, 10, counter)
        plt.imshow(rgb_frame)
        plt.axis('off')
    else:
        print(f"No video file exists in folder {selected_class_Name}")

plt.show()

# %%
# Set seed for reproducibility
mySeed = 42
np.random.seed(mySeed)
random.seed(mySeed)
torch.manual_seed(mySeed)

# %%
# Function to extract frames from a video
def frames_extraction(video_path):
    frames_list = []
    video_reader = cv2.VideoCapture(video_path)
    video_frames_count = int(video_reader.get(cv2.CAP_PROP_FRAME_COUNT))
    skip_frames_window = max(int(video_frames_count / num_frames), 1)
    
    for frame_counter in range(num_frames):
        video_reader.set(cv2.CAP_PROP_POS_FRAMES, frame_counter * skip_frames_window)
        success, frame = video_reader.read()
        if not success:
            break
        
        resized_frame = cv2.resize(frame, (height, width))
        normalized_frame = resized_frame / 255
        frames_list.append(normalized_frame)
    
    video_reader.release()
    return frames_list

# Custom PyTorch dataset
class VideoDataset(Dataset):
    def __init__(self, data, labels):
        self.data = data
        self.labels = labels

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        return torch.tensor(self.data[idx]), torch.tensor(self.labels[idx])

# Function to create dataset
def create_dataset():
    features = []
    labels = []
    video_files_paths = []

    for class_index, class_name in enumerate(CLASSES_LIST):
        print(f'Extracting Data of Class: {class_name}')

        files_list = os.listdir(os.path.join(DATASET_DIR, class_name))
        for file_name in files_list:
            video_file_path = os.path.join(DATASET_DIR, class_name, file_name)

            frames = frames_extraction(video_file_path)
            if len(frames) == num_frames:
                features.append(frames)
                labels.append(class_index)
                video_files_paths.append(video_file_path)

    features = np.asarray(features)
    labels = np.array(labels)

    return features, labels, video_files_paths

# %%
# Create dataset
features, labels, video_files_paths = create_dataset()

# Convert labels to one-hot encoding using PyTorch's F.one_hot
labels_one_hot = torch.tensor(np.eye(len(CLASSES_LIST))[labels])
# Out:
# Extracting Data of Class: Lunges
# Extracting Data of Class: MilitaryParade
# Extracting Data of Class: Mixing
# Extracting Data of Class: Nunchucks
# Extracting Data of Class: PizzaTossing
# Extracting Data of Class: PlayingGuitar
# Extracting Data of Class: PlayingPiano
# Extracting Data of Class: PlayingTabla
# Extracting Data of Class: PlayingViolin
# Extracting Data of Class: PoleVault

# %%
# Train-test split using sklearn's train_test_split
features_train, features_test, labels_train, labels_test = train_test_split(
    features, labels_one_hot, test_size=0.25, shuffle=True, random_state=mySeed
)

# Convert data to PyTorch tensors and move to GPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")


# Convert data to PyTorch tensors
features_train = torch.tensor(features_train).to(device)
labels_train = torch.tensor(labels_train).to(device)
features_test = torch.tensor(features_test).to(device)
labels_test = torch.tensor(labels_test).to(device)

# PyTorch DataLoader
train_dataset = VideoDataset(features_train, labels_train)
train_loader = DataLoader(train_dataset, batch_size=4, shuffle=True)

validation_dataset = VideoDataset(features_test, labels_test)
validation_loader = DataLoader(validation_dataset, batch_size=4, shuffle=True)
# Out:
# <ipython-input-7-b8a25bf621b5>:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   labels_train = torch.tensor(labels_train).to(device)
# <ipython-input-7-b8a25bf621b5>:14: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   labels_test = torch.tensor(labels_test).to(device)

# %%
class LRCNModel(nn.Module):
    def __init__(self):
        super(LRCNModel, self).__init__()

        self.conv1 = nn.Conv2d(3, 16, kernel_size=(3, 3), padding='same')  # Assuming input frames have 3 channels (RGB)
        self.pool1 = nn.MaxPool2d(kernel_size=(4, 4))
        self.dropout1 = nn.Dropout(0.25)

        self.conv2 = nn.Conv2d(16, 32, kernel_size=(3, 3), padding='same')
        self.pool2 = nn.MaxPool2d(kernel_size=(4, 4))
        self.dropout2 = nn.Dropout(0.25)

        self.conv3 = nn.Conv2d(32, 64, kernel_size=(3, 3), padding='same')
        self.pool3 = nn.MaxPool2d(kernel_size=(2, 2))
        self.dropout3 = nn.Dropout(0.25)

        self.conv4 = nn.Conv2d(64, 64, kernel_size=(3, 3), padding='same')
        self.pool4 = nn.MaxPool2d(kernel_size=(2, 2))

        self.flatten = nn.Flatten()
        self.lstm = nn.LSTM(64, 32)
        self.fc = nn.Linear(32, len(CLASSES_LIST))

    def forward(self, x):
        # Reshape input tensor to [batch_size * num_frames, channels, height, width]
        x = x.view(-1, x.shape[2], x.shape[3], x.shape[4])
        
        # Permute dimensions for convolutional layers
        x = x.permute(0, 3, 1, 2)

        x = self.dropout1(self.pool1(F.relu(self.conv1(x))))
        x = self.dropout2(self.pool2(F.relu(self.conv2(x))))
        x = self.dropout3(self.pool3(F.relu(self.conv3(x))))
        x = self.pool4(F.relu(self.conv4(x)))

        # Flatten the spatial dimensions
        x = self.flatten(x)

        # Permute dimensions for LSTM
        x = x.view(x.shape[0] // num_frames, num_frames, -1).permute(1, 0, 2)

        # Apply LSTM
        x, _ = self.lstm(x)
        x = x[-1, :, :]  # Take the output of the last time step

        # Fully connected layer
        x = self.fc(x)
        return F.softmax(x, dim=1)

# %%
# Instantiate the model and move to GPU
lrcn_model = LRCNModel().to(device)
print("Model Created Successfully!")

# before training
start_time = time.time()

# Define the loss function and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(lrcn_model.parameters())
# Out:
# Model Created Successfully!

# %%
# Training loop
num_epochs = 160

for epoch in range(num_epochs):
    lrcn_model.train()
    total_train_loss = 0
    correct_train_predictions = 0
    total_train_samples = 0

    for batch_idx, (inputs, targets) in enumerate(train_loader):
        inputs, targets = inputs.to(device), targets.to(device)

        optimizer.zero_grad()
        outputs = lrcn_model(inputs)

        loss = criterion(outputs, targets)
        loss.backward()
        optimizer.step()

        total_train_loss += loss.item()

        _, predicted = torch.max(outputs.data, 1)
        total_train_samples += targets.size(0)
        correct_train_predictions += (predicted == targets).sum().item()

    avg_train_loss = total_train_loss / len(train_loader)
    train_accuracy = correct_train_predictions / total_train_samples

    # Validation loop
    lrcn_model.eval()
    total_val_loss = 0
    correct_val_predictions = 0
    total_val_samples = 0

    with torch.no_grad():
        for batch_idx, (inputs, targets) in enumerate(validation_loader):
            inputs, targets = inputs.to(device), targets.to(device)

            outputs = lrcn_model(inputs)

            loss = criterion(outputs, targets)
            total_val_loss += loss.item()

            _, predicted = torch.max(outputs.data, 1)
            total_val_samples += targets.size(0)
            correct_val_predictions += (predicted == targets).sum().item()

    avg_val_loss = total_val_loss / len(validation_loader)
    val_accuracy = correct_val_predictions / total_val_samples

    # Print the loss and accuracy for each epoch
    print(f'Epoch [{epoch+1}/{num_epochs}], Training Loss: {avg_train_loss:.4f}, Training Accuracy: {train_accuracy:.4f}, Validation Loss: {avg_val_loss:.4f}, Validation Accuracy: {val_accuracy:.4f}')
# Out:
# Epoch [1/160], Training Loss: 2.6103, Training Accuracy: 0.1155, Validation Loss: 2.6303, Validation Accuracy: 0.0171
# Epoch [2/160], Training Loss: 2.6016, Training Accuracy: 0.1165, Validation Loss: 2.6198, Validation Accuracy: 0.0184
# Epoch [3/160], Training Loss: 2.5873, Training Accuracy: 0.1251, Validation Loss: 2.6073, Validation Accuracy: 0.0250
# Epoch [4/160], Training Loss: 2.5850, Training Accuracy: 0.1312, Validation Loss: 2.5979, Validation Accuracy: 0.0291
# Epoch [5/160], Training Loss: 2.5820, Training Accuracy: 0.1375, Validation Loss: 2.5781, Validation Accuracy: 0.0312
# Epoch [6/160], Training Loss: 2.5756, Training Accuracy: 0.1393, Validation Loss: 2.5679, Validation Accuracy: 0.0339
# Epoch [7/160], Training Loss: 2.5658, Training Accuracy: 0.1429, Validation Loss: 2.5539, Validation Accuracy: 0.0397
# Epoch [8/160], Training Loss: 2.5475, Training Accuracy: 0.1511, Validation Loss: 2.5356, Validation Accuracy: 0.0476
# Epoch [9/160], Training Loss: 2.5447, Training Accuracy: 0.1589, Validation Loss: 2.5205, Validation Accuracy: 0.0563
# Epoch [10/160], Training Loss: 2.5187, Training Accuracy: 0.1679, Validation Loss: 2.5150, Validation Accuracy: 0.0586
# Epoch [11/160], Training Loss: 2.5129, Training Accuracy: 0.1775, Validation Loss: 2.5105, Validation Accuracy: 0.0653
# Epoch [12/160], Training Loss: 2.5053, Training Accuracy: 0.1838, Validation Loss: 2.4860, Validation Accuracy: 0.0737
# Epoch [13/160], Training Loss: 2.4994, Training Accuracy: 0.1858, Validation Loss: 2.4785, Validation Accuracy: 0.0821
# Epoch [14/160], Training Loss: 2.4831, Training Accuracy: 0.1891, Validation Loss: 2.4614, Validation Accuracy: 0.0897
# Epoch [15/160], Training Loss: 2.4669, Training Accuracy: 0.1917, Validation Loss: 2.4410, Validation Accuracy: 0.0953
# Epoch [16/160], Training Loss: 2.4531, Training Accuracy: 0.1936, Validation Loss: 2.4212, Validation Accuracy: 0.1006
# Epoch [17/160], Training Loss: 2.4473, Training Accuracy: 0.1943, Validation Loss: 2.4030, Validation Accuracy: 0.1009
# Epoch [18/160], Training Loss: 2.4316, Training Accuracy: 0.2005, Validation Loss: 2.3825, Validation Accuracy: 0.1056
# Epoch [19/160], Training Loss: 2.4293, Training Accuracy: 0.2026, Validation Loss: 2.3762, Validation Accuracy: 0.1143
# Epoch [20/160], Training Loss: 2.4079, Training Accuracy: 0.2039, Validation Loss: 2.3653, Validation Accuracy: 0.1188
# Epoch [21/160], Training Loss: 2.3827, Training Accuracy: 0.2055, Validation Loss: 2.3598, Validation Accuracy: 0.1260
# Epoch [22/160], Training Loss: 2.3750, Training Accuracy: 0.2065, Validation Loss: 2.3390, Validation Accuracy: 0.1345
# Epoch [23/160], Training Loss: 2.3586, Training Accuracy: 0.2143, Validation Loss: 2.3362, Validation Accuracy: 0.1400
# Epoch [24/160], Training Loss: 2.3399, Training Accuracy: 0.2238, Validation Loss: 2.3089, Validation Accuracy: 0.1451
# Epoch [25/160], Training Loss: 2.3182, Training Accuracy: 0.2301, Validation Loss: 2.3074, Validation Accuracy: 0.1548
# Epoch [26/160], Training Loss: 2.3149, Training Accuracy: 0.2336, Validation Loss: 2.3017, Validation Accuracy: 0.1570
# Epoch [27/160], Training Loss: 2.2906, Training Accuracy: 0.2354, Validation Loss: 2.2813, Validation Accuracy: 0.1601
# Epoch [28/160], Training Loss: 2.2663, Training Accuracy: 0.2410, Validation Loss: 2.2721, Validation Accuracy: 0.1700
# Epoch [29/160], Training Loss: 2.2404, Training Accuracy: 0.2427, Validation Loss: 2.2509, Validation Accuracy: 0.1746
# Epoch [30/160], Training Loss: 2.2317, Training Accuracy: 0.2516, Validation Loss: 2.2369, Validation Accuracy: 0.1817
# Epoch [31/160], Training Loss: 2.2118, Training Accuracy: 0.2575, Validation Loss: 2.2102, Validation Accuracy: 0.1839
# Epoch [32/160], Training Loss: 2.1959, Training Accuracy: 0.2585, Validation Loss: 2.1852, Validation Accuracy: 0.1880
# Epoch [33/160], Training Loss: 2.1683, Training Accuracy: 0.2661, Validation Loss: 2.1709, Validation Accuracy: 0.1965
# Epoch [34/160], Training Loss: 2.1518, Training Accuracy: 0.2737, Validation Loss: 2.1592, Validation Accuracy: 0.2024
# Epoch [35/160], Training Loss: 2.1414, Training Accuracy: 0.2741, Validation Loss: 2.1335, Validation Accuracy: 0.2117
# Epoch [36/160], Training Loss: 2.1274, Training Accuracy: 0.2743, Validation Loss: 2.1190, Validation Accuracy: 0.2163
# Epoch [37/160], Training Loss: 2.1098, Training Accuracy: 0.2780, Validation Loss: 2.1035, Validation Accuracy: 0.2165
# Epoch [38/160], Training Loss: 2.0886, Training Accuracy: 0.2802, Validation Loss: 2.0759, Validation Accuracy: 0.2231
# Epoch [39/160], Training Loss: 2.0801, Training Accuracy: 0.2826, Validation Loss: 2.0646, Validation Accuracy: 0.2259
# Epoch [40/160], Training Loss: 2.0609, Training Accuracy: 0.2871, Validation Loss: 2.0378, Validation Accuracy: 0.2278
# Epoch [41/160], Training Loss: 2.0376, Training Accuracy: 0.2925, Validation Loss: 2.0305, Validation Accuracy: 0.2309
# Epoch [42/160], Training Loss: 2.0264, Training Accuracy: 0.3019, Validation Loss: 2.0241, Validation Accuracy: 0.2332
# Epoch [43/160], Training Loss: 2.0105, Training Accuracy: 0.3115, Validation Loss: 2.0039, Validation Accuracy: 0.2413
# Epoch [44/160], Training Loss: 1.9837, Training Accuracy: 0.3164, Validation Loss: 2.0008, Validation Accuracy: 0.2415
# Epoch [45/160], Training Loss: 1.9701, Training Accuracy: 0.3189, Validation Loss: 1.9795, Validation Accuracy: 0.2496
# Epoch [46/160], Training Loss: 1.9523, Training Accuracy: 0.3204, Validation Loss: 1.9723, Validation Accuracy: 0.2563
# Epoch [47/160], Training Loss: 1.9341, Training Accuracy: 0.3216, Validation Loss: 1.9541, Validation Accuracy: 0.2589
# Epoch [48/160], Training Loss: 1.9299, Training Accuracy: 0.3219, Validation Loss: 1.9363, Validation Accuracy: 0.2640
# Epoch [49/160], Training Loss: 1.9151, Training Accuracy: 0.3268, Validation Loss: 1.9329, Validation Accuracy: 0.2661
# Epoch [50/160], Training Loss: 1.9064, Training Accuracy: 0.3308, Validation Loss: 1.9070, Validation Accuracy: 0.2679
# Epoch [51/160], Training Loss: 1.8929, Training Accuracy: 0.3400, Validation Loss: 1.8876, Validation Accuracy: 0.2714
# Epoch [52/160], Training Loss: 1.8731, Training Accuracy: 0.3458, Validation Loss: 1.8756, Validation Accuracy: 0.2746
# Epoch [53/160], Training Loss: 1.8544, Training Accuracy: 0.3472, Validation Loss: 1.8487, Validation Accuracy: 0.2811
# Epoch [54/160], Training Loss: 1.8530, Training Accuracy: 0.3475, Validation Loss: 1.8280, Validation Accuracy: 0.2817
# Epoch [55/160], Training Loss: 1.8270, Training Accuracy: 0.3539, Validation Loss: 1.8170, Validation Accuracy: 0.2838
# Epoch [56/160], Training Loss: 1.8171, Training Accuracy: 0.3625, Validation Loss: 1.8143, Validation Accuracy: 0.2877
# Epoch [57/160], Training Loss: 1.8098, Training Accuracy: 0.3718, Validation Loss: 1.7873, Validation Accuracy: 0.2900
# Epoch [58/160], Training Loss: 1.7916, Training Accuracy: 0.3762, Validation Loss: 1.7694, Validation Accuracy: 0.2941
# Epoch [59/160], Training Loss: 1.7817, Training Accuracy: 0.3825, Validation Loss: 1.7667, Validation Accuracy: 0.2965
# Epoch [60/160], Training Loss: 1.7689, Training Accuracy: 0.3886, Validation Loss: 1.7528, Validation Accuracy: 0.3001
# Epoch [61/160], Training Loss: 1.7476, Training Accuracy: 0.3913, Validation Loss: 1.7278, Validation Accuracy: 0.3051
# Epoch [62/160], Training Loss: 1.7299, Training Accuracy: 0.3987, Validation Loss: 1.7147, Validation Accuracy: 0.3125
# Epoch [63/160], Training Loss: 1.7137, Training Accuracy: 0.4059, Validation Loss: 1.7132, Validation Accuracy: 0.3135
# Epoch [64/160], Training Loss: 1.6988, Training Accuracy: 0.4074, Validation Loss: 1.6885, Validation Accuracy: 0.3190
# Epoch [65/160], Training Loss: 1.6947, Training Accuracy: 0.4166, Validation Loss: 1.6723, Validation Accuracy: 0.3222
# Epoch [66/160], Training Loss: 1.6892, Training Accuracy: 0.4231, Validation Loss: 1.6528, Validation Accuracy: 0.3316
# Epoch [67/160], Training Loss: 1.6756, Training Accuracy: 0.4247, Validation Loss: 1.6485, Validation Accuracy: 0.3346
# Epoch [68/160], Training Loss: 1.6723, Training Accuracy: 0.4268, Validation Loss: 1.6375, Validation Accuracy: 0.3395
# Epoch [69/160], Training Loss: 1.6475, Training Accuracy: 0.4355, Validation Loss: 1.6148, Validation Accuracy: 0.3417
# Epoch [70/160], Training Loss: 1.6202, Training Accuracy: 0.4418, Validation Loss: 1.6016, Validation Accuracy: 0.3437
# Epoch [71/160], Training Loss: 1.6069, Training Accuracy: 0.4509, Validation Loss: 1.5899, Validation Accuracy: 0.3507
# Epoch [72/160], Training Loss: 1.6055, Training Accuracy: 0.4557, Validation Loss: 1.5810, Validation Accuracy: 0.3531
# Epoch [73/160], Training Loss: 1.5994, Training Accuracy: 0.4561, Validation Loss: 1.5549, Validation Accuracy: 0.3567
# Epoch [74/160], Training Loss: 1.5833, Training Accuracy: 0.4627, Validation Loss: 1.5450, Validation Accuracy: 0.3580
# Epoch [75/160], Training Loss: 1.5761, Training Accuracy: 0.4709, Validation Loss: 1.5341, Validation Accuracy: 0.3584
# Epoch [76/160], Training Loss: 1.5596, Training Accuracy: 0.4804, Validation Loss: 1.5303, Validation Accuracy: 0.3672
# Epoch [77/160], Training Loss: 1.5357, Training Accuracy: 0.4872, Validation Loss: 1.5067, Validation Accuracy: 0.3702
# Epoch [78/160], Training Loss: 1.5169, Training Accuracy: 0.4883, Validation Loss: 1.5037, Validation Accuracy: 0.3718
# Epoch [79/160], Training Loss: 1.4955, Training Accuracy: 0.4928, Validation Loss: 1.4926, Validation Accuracy: 0.3806
# Epoch [80/160], Training Loss: 1.4756, Training Accuracy: 0.4979, Validation Loss: 1.4788, Validation Accuracy: 0.3889
# Epoch [81/160], Training Loss: 1.4726, Training Accuracy: 0.5014, Validation Loss: 1.4549, Validation Accuracy: 0.3918
# Epoch [82/160], Training Loss: 1.4607, Training Accuracy: 0.5058, Validation Loss: 1.4493, Validation Accuracy: 0.3936
# Epoch [83/160], Training Loss: 1.4335, Training Accuracy: 0.5094, Validation Loss: 1.4225, Validation Accuracy: 0.3979
# Epoch [84/160], Training Loss: 1.4228, Training Accuracy: 0.5153, Validation Loss: 1.4149, Validation Accuracy: 0.4016
# Epoch [85/160], Training Loss: 1.4081, Training Accuracy: 0.5221, Validation Loss: 1.4036, Validation Accuracy: 0.4021
# Epoch [86/160], Training Loss: 1.3929, Training Accuracy: 0.5253, Validation Loss: 1.3970, Validation Accuracy: 0.4092
# Epoch [87/160], Training Loss: 1.3668, Training Accuracy: 0.5310, Validation Loss: 1.3706, Validation Accuracy: 0.4144
# Epoch [88/160], Training Loss: 1.3443, Training Accuracy: 0.5373, Validation Loss: 1.3587, Validation Accuracy: 0.4173
# Epoch [89/160], Training Loss: 1.3358, Training Accuracy: 0.5376, Validation Loss: 1.3536, Validation Accuracy: 0.4260
# Epoch [90/160], Training Loss: 1.3206, Training Accuracy: 0.5444, Validation Loss: 1.3406, Validation Accuracy: 0.4313
# Epoch [91/160], Training Loss: 1.2997, Training Accuracy: 0.5535, Validation Loss: 1.3191, Validation Accuracy: 0.4385
# Epoch [92/160], Training Loss: 1.2875, Training Accuracy: 0.5599, Validation Loss: 1.3075, Validation Accuracy: 0.4399
# Epoch [93/160], Training Loss: 1.2682, Training Accuracy: 0.5642, Validation Loss: 1.2882, Validation Accuracy: 0.4468
# Epoch [94/160], Training Loss: 1.2605, Training Accuracy: 0.5691, Validation Loss: 1.2735, Validation Accuracy: 0.4519
# Epoch [95/160], Training Loss: 1.2407, Training Accuracy: 0.5697, Validation Loss: 1.2461, Validation Accuracy: 0.4569
# Epoch [96/160], Training Loss: 1.2384, Training Accuracy: 0.5762, Validation Loss: 1.2238, Validation Accuracy: 0.4664
# Epoch [97/160], Training Loss: 1.2236, Training Accuracy: 0.5798, Validation Loss: 1.2193, Validation Accuracy: 0.4717
# Epoch [98/160], Training Loss: 1.2099, Training Accuracy: 0.5855, Validation Loss: 1.2138, Validation Accuracy: 0.4730
# Epoch [99/160], Training Loss: 1.2012, Training Accuracy: 0.5919, Validation Loss: 1.2061, Validation Accuracy: 0.4790
# Epoch [100/160], Training Loss: 1.1884, Training Accuracy: 0.5964, Validation Loss: 1.1833, Validation Accuracy: 0.4883
# Epoch [101/160], Training Loss: 1.1738, Training Accuracy: 0.6036, Validation Loss: 1.1757, Validation Accuracy: 0.4885
# Epoch [102/160], Training Loss: 1.1639, Training Accuracy: 0.6040, Validation Loss: 1.1508, Validation Accuracy: 0.4946
# Epoch [103/160], Training Loss: 1.1571, Training Accuracy: 0.6047, Validation Loss: 1.1318, Validation Accuracy: 0.4971
# Epoch [104/160], Training Loss: 1.1344, Training Accuracy: 0.6097, Validation Loss: 1.1174, Validation Accuracy: 0.5067
# Epoch [105/160], Training Loss: 1.1100, Training Accuracy: 0.6150, Validation Loss: 1.0982, Validation Accuracy: 0.5121
# Epoch [106/160], Training Loss: 1.0981, Training Accuracy: 0.6218, Validation Loss: 1.0839, Validation Accuracy: 0.5161
# Epoch [107/160], Training Loss: 1.0745, Training Accuracy: 0.6245, Validation Loss: 1.0823, Validation Accuracy: 0.5231
# Epoch [108/160], Training Loss: 1.0563, Training Accuracy: 0.6292, Validation Loss: 1.0763, Validation Accuracy: 0.5261
# Epoch [109/160], Training Loss: 1.0500, Training Accuracy: 0.6355, Validation Loss: 1.0700, Validation Accuracy: 0.5294
# Epoch [110/160], Training Loss: 1.0481, Training Accuracy: 0.6377, Validation Loss: 1.0576, Validation Accuracy: 0.5322
# Epoch [111/160], Training Loss: 1.0384, Training Accuracy: 0.6430, Validation Loss: 1.0303, Validation Accuracy: 0.5327
# Epoch [112/160], Training Loss: 1.0312, Training Accuracy: 0.6472, Validation Loss: 1.0229, Validation Accuracy: 0.5355
# Epoch [113/160], Training Loss: 1.0187, Training Accuracy: 0.6510, Validation Loss: 0.9994, Validation Accuracy: 0.5394
# Epoch [114/160], Training Loss: 1.0131, Training Accuracy: 0.6543, Validation Loss: 0.9754, Validation Accuracy: 0.5491
# Epoch [115/160], Training Loss: 1.0103, Training Accuracy: 0.6641, Validation Loss: 0.9503, Validation Accuracy: 0.5560
# Epoch [116/160], Training Loss: 0.9864, Training Accuracy: 0.6700, Validation Loss: 0.9407, Validation Accuracy: 0.5583
# Epoch [117/160], Training Loss: 0.9829, Training Accuracy: 0.6727, Validation Loss: 0.9359, Validation Accuracy: 0.5677
# Epoch [118/160], Training Loss: 0.9585, Training Accuracy: 0.6795, Validation Loss: 0.9134, Validation Accuracy: 0.5711
# Epoch [119/160], Training Loss: 0.9445, Training Accuracy: 0.6878, Validation Loss: 0.8937, Validation Accuracy: 0.5721
# Epoch [120/160], Training Loss: 0.9256, Training Accuracy: 0.6902, Validation Loss: 0.8752, Validation Accuracy: 0.5750
# Epoch [121/160], Training Loss: 0.9147, Training Accuracy: 0.6941, Validation Loss: 0.8656, Validation Accuracy: 0.5830
# Epoch [122/160], Training Loss: 0.8933, Training Accuracy: 0.7019, Validation Loss: 0.8525, Validation Accuracy: 0.5834
# Epoch [123/160], Training Loss: 0.8732, Training Accuracy: 0.7064, Validation Loss: 0.8321, Validation Accuracy: 0.5864
# Epoch [124/160], Training Loss: 0.8536, Training Accuracy: 0.7072, Validation Loss: 0.8134, Validation Accuracy: 0.5886
# Epoch [125/160], Training Loss: 0.8329, Training Accuracy: 0.7105, Validation Loss: 0.7887, Validation Accuracy: 0.5948
# Epoch [126/160], Training Loss: 0.8310, Training Accuracy: 0.7110, Validation Loss: 0.7824, Validation Accuracy: 0.5968
# Epoch [127/160], Training Loss: 0.8107, Training Accuracy: 0.7140, Validation Loss: 0.7621, Validation Accuracy: 0.6034
# Epoch [128/160], Training Loss: 0.7945, Training Accuracy: 0.7192, Validation Loss: 0.7409, Validation Accuracy: 0.6114
# Epoch [129/160], Training Loss: 0.7808, Training Accuracy: 0.7223, Validation Loss: 0.7377, Validation Accuracy: 0.6201
# Epoch [130/160], Training Loss: 0.7692, Training Accuracy: 0.7299, Validation Loss: 0.7253, Validation Accuracy: 0.6234
# Epoch [131/160], Training Loss: 0.7553, Training Accuracy: 0.7394, Validation Loss: 0.7143, Validation Accuracy: 0.6293
# Epoch [132/160], Training Loss: 0.7464, Training Accuracy: 0.7418, Validation Loss: 0.6890, Validation Accuracy: 0.6393
# Epoch [133/160], Training Loss: 0.7330, Training Accuracy: 0.7478, Validation Loss: 0.6857, Validation Accuracy: 0.6400
# Epoch [134/160], Training Loss: 0.7284, Training Accuracy: 0.7558, Validation Loss: 0.6704, Validation Accuracy: 0.6405
# Epoch [135/160], Training Loss: 0.7089, Training Accuracy: 0.7568, Validation Loss: 0.6596, Validation Accuracy: 0.6496
# Epoch [136/160], Training Loss: 0.6962, Training Accuracy: 0.7596, Validation Loss: 0.6458, Validation Accuracy: 0.6503
# Epoch [137/160], Training Loss: 0.6925, Training Accuracy: 0.7609, Validation Loss: 0.6225, Validation Accuracy: 0.6586
# Epoch [138/160], Training Loss: 0.6890, Training Accuracy: 0.7670, Validation Loss: 0.6210, Validation Accuracy: 0.6637
# Epoch [139/160], Training Loss: 0.6859, Training Accuracy: 0.7678, Validation Loss: 0.6186, Validation Accuracy: 0.6650
# Epoch [140/160], Training Loss: 0.6581, Training Accuracy: 0.7767, Validation Loss: 0.6057, Validation Accuracy: 0.6653
# Epoch [141/160], Training Loss: 0.6377, Training Accuracy: 0.7814, Validation Loss: 0.6040, Validation Accuracy: 0.6704
# Epoch [142/160], Training Loss: 0.6346, Training Accuracy: 0.7867, Validation Loss: 0.5986, Validation Accuracy: 0.6785
# Epoch [143/160], Training Loss: 0.6096, Training Accuracy: 0.7922, Validation Loss: 0.5750, Validation Accuracy: 0.6859
# Epoch [144/160], Training Loss: 0.5866, Training Accuracy: 0.7944, Validation Loss: 0.5666, Validation Accuracy: 0.6903
# Epoch [145/160], Training Loss: 0.5787, Training Accuracy: 0.7959, Validation Loss: 0.5432, Validation Accuracy: 0.6914
# Epoch [146/160], Training Loss: 0.5727, Training Accuracy: 0.8050, Validation Loss: 0.5289, Validation Accuracy: 0.6948
# Epoch [147/160], Training Loss: 0.5497, Training Accuracy: 0.8118, Validation Loss: 0.5047, Validation Accuracy: 0.7023
# Epoch [148/160], Training Loss: 0.5286, Training Accuracy: 0.8144, Validation Loss: 0.4829, Validation Accuracy: 0.7029
# Epoch [149/160], Training Loss: 0.5086, Training Accuracy: 0.8242, Validation Loss: 0.4742, Validation Accuracy: 0.7064
# Epoch [150/160], Training Loss: 0.4991, Training Accuracy: 0.8331, Validation Loss: 0.4478, Validation Accuracy: 0.7134
# Epoch [151/160], Training Loss: 0.4818, Training Accuracy: 0.8342, Validation Loss: 0.4332, Validation Accuracy: 0.7164
# Epoch [152/160], Training Loss: 0.4621, Training Accuracy: 0.8351, Validation Loss: 0.4083, Validation Accuracy: 0.7235
# Epoch [153/160], Training Loss: 0.4505, Training Accuracy: 0.8438, Validation Loss: 0.3861, Validation Accuracy: 0.7320
# Epoch [154/160], Training Loss: 0.4423, Training Accuracy: 0.8497, Validation Loss: 0.3742, Validation Accuracy: 0.7365
# Epoch [155/160], Training Loss: 0.4269, Training Accuracy: 0.8531, Validation Loss: 0.3605, Validation Accuracy: 0.7444
# Epoch [156/160], Training Loss: 0.4055, Training Accuracy: 0.8545, Validation Loss: 0.3526, Validation Accuracy: 0.7536
# Epoch [157/160], Training Loss: 0.3893, Training Accuracy: 0.8637, Validation Loss: 0.3433, Validation Accuracy: 0.7580
# Epoch [158/160], Training Loss: 0.3630, Training Accuracy: 0.8687, Validation Loss: 0.3299, Validation Accuracy: 0.7623
# Epoch [159/160], Training Loss: 0.3390, Training Accuracy: 0.8736, Validation Loss: 0.3106, Validation Accuracy: 0.7712
# Epoch [160/160], Training Loss: 0.3164, Training Accuracy: 0.8827, Validation Loss: 0.2981, Validation Accuracy: 0.7761
